# %% [markdown]
# <b><font size="5">Pandas Dataframes: Charachteristics and Manipulation</font></b>
# <br><br>
# In this notebook, we will take at some additional aspects of what can be done using the very flexible constructs that are pandas dataframes. As per usual, you are encouraged to complement your knowledge using the documentation that is available online:<br>
# https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html
#
# ### <font color='#BFD72F'>Table of Contents </font> <a class="anchor" id='toc'></a>
# - [0. Importing packages and Data](#P0)
# - [1. Data Exploration](#P1)
#     - [Attributes](#P1.1)
#     - [Basic inspection](#P1.2)
#     - [Descriptive statistics](#P1.3)
# - [2. Grouping and Aggregation](#P2)
# - [3. Cross tabulation and Pivoting](#P3)
#     - [CrossTab](#P3.1)
#     - [Pivot Tables](#P3.2)
# - [4. Grabbing subsets - Advanced options](#P4)
# - [5. Try it out](#P5)

# %% [markdown]
# ### <font color='#BFD72F'>0. Importing packages and Data</font> <a class="anchor" id="P0"></a>
#   [Back to TOC](#toc)
#
# The first step you should take in any Data Science project that with jupyter notebooks should be importing the packages and data that you intend to use. In this notebook we will exclusively used the *pandas* package. However, in the real world, you will regularly find projects where you will need to call dozens of different packages and/or functions.<br>
# While importing packages as you go is possible, importing every package right from the start is considered a *good practice* as it will allow you to keep your notebooks clean and organized, which will definitely come in handy in situations where you need to revisit a notebook.
#
#   <b>Step 0.1</b>: Import *pandas* and *numpy*

# %%
from sys import modules as notebook_modules

import pandas as pd
import numpy as np

print(f"Pandas version: {pd.__version__}\nNumPy version: {np.__version__}")
# Out:
# Pandas version: 2.2.2
# NumPy version: 1.26.4

# %% [markdown]
#   <b>Step 0.2</b>: Import the csv file *pop_censuspt_2021.csv* that is stored in folder *data* and store it in variable *population*.

# %%
#always pay attention to the path and the separator used in the csv (Portuguese csvs by default use ";"" instead of ",")
population = pd.read_csv(r"./data/pop_censuspt_2021.csv", sep=";")

# %% [markdown]
# ### <font color='#BFD72F'>1. Data Exploration</font> <a class="anchor" id="P1"></a>
#   [Back to TOC](#toc)
#
# Every problem has its own intrincacies so whenever you start working with new data, you should take the time to get yourself familiar with it, what variables are present and what the meaning of each variable is. In this notebook, we will use an adapted version of the Population Census 2021 collected from Instituto Nacional de Estatística (INE). For every parish, you will find the official population numbers stratified by sex and age group bracket. For every parish, there are 8 rows (Age brackets: 0-14, 15-24, 25-64, 65 or older for both males and females).
#
# In this section, we will use different pandas methods to explore the data and get a better understanding of it.
#
# #### Attributes <a class="anchor" id="P1.1"></a>
#
# A pandas dataframe is a two-dimensional data structure, i.e., it is a table with rows and columns, each having its own index. You can tell the number of rows and columns of a dataframe by using the `shape` attribute.
#
# **Step 1.1** Use the `shape` attribute to find out the number of rows and columns of the dataframe.

# %%
#[number of rows, number of columns]
population.shape
# Out:
# (24728, 10)

# %% [markdown]
# To be able to tell the index of the dataset you can use the `index` attribute on the dataframe.
#
# **Step 1.2** Use the *columns* attribute to see the columns of the dataframe.

# %%
population.index
# Out:
# RangeIndex(start=0, stop=24728, step=1)

# %% [markdown]
# To access the names of the columns in the dataset you can use the `columns` attribute on the dataframe.
#
# **Step 1.3** Use the *columns* attribute to see the columns of the dataframe.

# %%
population.columns.tolist()
# Out:
# ['Year',
#  'Location_Code',
#  'District',
#  'Municipality',
#  'Parish',
#  'Sex',
#  'Age',
#  'Population',
#  'Notes',
#  'Population_corrected']

# %% [markdown]
# Using `dtypes` you can also access the names of the different columns whilst also knowing the datatype they contain.
#
# **Step 1.4** Use the `dtypes` attribute to print the names of the columns and their datatypes.

# %%
population.dtypes
# Out:
# Year                      int64
# Location_Code            object
# District                 object
# Municipality             object
# Parish                   object
# Sex                      object
# Age                      object
# Population                int64
# Notes                   float64
# Population_corrected      int64
# dtype: object

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24728 entries, 0 to 24727
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  24728 non-null  int64
#  1   Location_Code         24728 non-null  object
#  2   District              24728 non-null  object
#  3   Municipality          24728 non-null  object
#  4   Parish                24728 non-null  object
#  5   Sex                   24728 non-null  object
#  6   Age                   24728 non-null  object
#  7   Population            24728 non-null  int64
#  8   Notes                 0 non-null      float64
#  9   Population_corrected  24728 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.9+ MB

# %%
#in case you want to change a dtype you can use the astype()-method
#eventhough it makes more sense to keep year as an integer, here is the general idea:
population['Year'] = population['Year'].astype('float')

# %% [markdown]
# **Exercise**
#
# In some cases, columns may come with a name that is not suitable for your analysis. For example, the column `Age` may intuitively imply that it should be numerical (as age is generally represented by a number). Later in this notebook, you will be able to tell column `Age` is constituted by different age brackets. In this case, it would be more appropriate to rename the column `Age` to `Age_bracket`.
#
# **Step 1.5** Rename the column `Age` to `Age_bracket` in the `population` dataframe.
#
# As there are multiple ways to rename columns, we will start with the creation of a copy of the dataframe.
# **Step 1.5.0** Run the cell below to create 2 distinct copies of the `population` dataframe.

# %%
#creating 2 copies of the population dataframe
population_copy_1 = population.copy()
population_copy_2 = population.copy()

# %% [markdown]
# **Step 1.5.1** Edit the name of column `Age` in `population_copy_1` exclusively using the `columns` attribute and lists.
#
# **Step 1.5.1.1** Create a list of the column names of `population_copy_1` using the `columns` attribute.

# %%
column_list = population_copy_1.columns.tolist()
type(column_list)
# Out:
# list

# %% [markdown]
# **Step 1.5.2.2** Use list indexing to edit "Age" to "Age_bracket".

# %%
column_list[-4] = "Age_bracket"

# %% [markdown]
# **Step 1.5.1.3** Assign the updated list of column names as the new columns attribute of `population_copy_1`

# %%
population_copy_1.columns = column_list

# %% [markdown]
# **Step 1.5.1.4** Check whether your changes took effect by looking at the columns of `population_copy_1`

# %%
population_copy_1
# Out:
#          Year Location_Code       District          Municipality  \
# 0      2021.0        170320      Vila Real                Chaves
# 1      2021.0         91205         Guarda                  Seia
# 2      2021.0         10416         Aveiro                Arouca
# 3      2021.0         31360          Braga            Vila Verde
# 4      2021.0        130526          Porto               Lousada
# ...       ...           ...            ...                   ...
# 24723  2021.0         40542       Bragança  Macedo de Cavaleiros
# 24724  2021.0        140503       Santarém             Benavente
# 24725  2021.0        430101  Ilha Terceira     Angra do Heroísmo
# 24726  2021.0        171305      Vila Real  Vila Pouca de Aguiar
# 24727  2021.0        130526          Porto               Lousada
#
#                                                   Parish Sex  \
# 0                                                   Oura   F
# 1                                             Girabolhos   M
# 2                                          Santa Eulália   M
# 3               União das freguesias da Ribeira do Neiva   M
# 4                               Vilar do Torno e Alentém   M
# ...                                                  ...  ..
# 24723  União das freguesias de Espadanedo, Edroso, Mu...   M
# 24724                                      Santo Estêvão   F
# 24725                                            Altares   F
# 24726                                          Capeludos   F
# 24727                           Vilar do Torno e Alentém   M
#
#             Age_bracket  Population  Notes  Population_corrected
# 0          65 and older         100    NaN                   100
# 1       0 - 14 year old           5    NaN                     5
# 2       0 - 14 year old         137    NaN                   137
# 3       0 - 14 year old         203    NaN                   203
# 4      25 - 64 year old         346    NaN                   346
# ...                 ...         ...    ...                   ...
# 24723      65 and older          76    NaN                    76
# 24724   0 - 14 year old         124    NaN                   124
# 24725  25 - 64 year old         235    NaN                   235
# 24726   0 - 14 year old           5    NaN                     5
# 24727  15 - 24 year old          68    NaN                    68
#
# [24728 rows x 10 columns]

# %% [markdown]
# An alternative method that allows you to edit the name of one or more columns is through the `rename()` method. You can access its documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html).
#
# **Step 1.5.2.1** Use the method `rename()` to change `Age` to `Age_bracket` in `population_copy_2`.

# %%
#Note - You will need to expliclty say that you want to change a column, which column to change and the new name of the column
population_copy_2.rename(mapper={"Age":"Age_bracket"}, axis=1, inplace=True)

# Alternatively I can do simply (column=dict)...

# %% [markdown]
# **Step 1.5.2.2** Check whether your changes took effect by looking at the columns of `population_copy_2`.

# %%
population_copy_2
# Out:
#          Year Location_Code       District          Municipality  \
# 0      2021.0        170320      Vila Real                Chaves
# 1      2021.0         91205         Guarda                  Seia
# 2      2021.0         10416         Aveiro                Arouca
# 3      2021.0         31360          Braga            Vila Verde
# 4      2021.0        130526          Porto               Lousada
# ...       ...           ...            ...                   ...
# 24723  2021.0         40542       Bragança  Macedo de Cavaleiros
# 24724  2021.0        140503       Santarém             Benavente
# 24725  2021.0        430101  Ilha Terceira     Angra do Heroísmo
# 24726  2021.0        171305      Vila Real  Vila Pouca de Aguiar
# 24727  2021.0        130526          Porto               Lousada
#
#                                                   Parish Sex  \
# 0                                                   Oura   F
# 1                                             Girabolhos   M
# 2                                          Santa Eulália   M
# 3               União das freguesias da Ribeira do Neiva   M
# 4                               Vilar do Torno e Alentém   M
# ...                                                  ...  ..
# 24723  União das freguesias de Espadanedo, Edroso, Mu...   M
# 24724                                      Santo Estêvão   F
# 24725                                            Altares   F
# 24726                                          Capeludos   F
# 24727                           Vilar do Torno e Alentém   M
#
#             Age_bracket  Population  Notes  Population_corrected
# 0          65 and older         100    NaN                   100
# 1       0 - 14 year old           5    NaN                     5
# 2       0 - 14 year old         137    NaN                   137
# 3       0 - 14 year old         203    NaN                   203
# 4      25 - 64 year old         346    NaN                   346
# ...                 ...         ...    ...                   ...
# 24723      65 and older          76    NaN                    76
# 24724   0 - 14 year old         124    NaN                   124
# 24725  25 - 64 year old         235    NaN                   235
# 24726   0 - 14 year old           5    NaN                     5
# 24727  15 - 24 year old          68    NaN                    68
#
# [24728 rows x 10 columns]

# %% [markdown]
# **Step 1.5.3** Using one of the methods above (or another method you can come up with), rename columns `Age` and `Notes` on the original dataframe `population` to `Age_bracket` and `Comments`. Run all the code in a single cell (including verification).

# %%
#changing column names
population.rename(mapper={"Age": "Age_bracket", "Notes":"Comments"}, axis=1, inplace=True)

#checking
print(population.columns.tolist())
# Out:
# ['Year', 'Location_Code', 'District', 'Municipality', 'Parish', 'Sex', 'Age_bracket', 'Population', 'Comments', 'Population_corrected']

# %% [markdown]
# #### Basic Inspection <a class="anchor" id="P1.2"></a>
#
# More than just having the shape of the data, it is important to know what the data looks like. There are multiple methods that allow you to that and this section will cover the most important ones.
#
# **Step 1.6** Use the method `head` on dataframe `population` to look at the first rows of a dataframe (default = 5).

# %%
population.head()
# Out:
#      Year Location_Code   District Municipality  \
# 0  2021.0        170320  Vila Real       Chaves
# 1  2021.0         91205     Guarda         Seia
# 2  2021.0         10416     Aveiro       Arouca
# 3  2021.0         31360      Braga   Vila Verde
# 4  2021.0        130526      Porto      Lousada
#
#                                      Parish Sex       Age_bracket  Population  \
# 0                                      Oura   F      65 and older         100
# 1                                Girabolhos   M   0 - 14 year old           5
# 2                             Santa Eulália   M   0 - 14 year old         137
# 3  União das freguesias da Ribeira do Neiva   M   0 - 14 year old         203
# 4                  Vilar do Torno e Alentém   M  25 - 64 year old         346
#
#    Comments  Population_corrected
# 0       NaN                   100
# 1       NaN                     5
# 2       NaN                   137
# 3       NaN                   203
# 4       NaN                   346

# %%
#While checking the head you notice that you prefer explicitly stating the Sex instead of using 'F' and 'M'

#so you check the unique values covered in Sex
print(population['Sex'].unique())
#in this case it's just F/M, so we can replace using the following
population['Sex'] = population['Sex'].replace({'M': 'Male', 'F': 'Female'})
# Out:
# ['F' 'M']

# %%
list(population['Sex'].unique())

# nunique returns dimension of the list...
# Out:
# ['Female', 'Male']

# %% [markdown]
# **Step 1.6.1** Use, again, the method `head` on dataframe `population` to look at the first 50 rows.

# %%
population.head(50)
# Out:
#       Year Location_Code             District          Municipality  \
# 0   2021.0        170320            Vila Real                Chaves
# 1   2021.0         91205               Guarda                  Seia
# 2   2021.0         10416               Aveiro                Arouca
# 3   2021.0         31360                Braga            Vila Verde
# 4   2021.0        130526                Porto               Lousada
# 5   2021.0         90628               Guarda               Gouveia
# 6   2021.0        130811                Porto            Matosinhos
# 7   2021.0         30301                Braga                 Braga
# 8   2021.0         30922                Braga      Póvoa de Lanhoso
# 9   2021.0        151101              Setúbal              Sesimbra
# 10  2021.0        150803              Setúbal               Palmela
# 11  2021.0         30931                Braga      Póvoa de Lanhoso
# 12  2021.0        160820     Viana do Castelo               Valença
# 13  2021.0        160816     Viana do Castelo               Valença
# 14  2021.0         61310              Coimbra              Penacova
# 15  2021.0        160218     Viana do Castelo     Arcos de Valdevez
# 16  2021.0        181908                Viseu               Tabuaço
# 17  2021.0        160130     Viana do Castelo     Arcos de Valdevez
# 18  2021.0         40604             Bragança      Miranda do Douro
# 19  2021.0        111323               Lisboa         Torres Vedras
# 20  2021.0         50205       Castelo Branco        Castelo Branco
# 21  2021.0        120504           Portalegre       Castelo de Vide
# 22  2021.0        131506                Porto               Valongo
# 23  2021.0         20210                 Beja             Almodôvar
# 24  2021.0         40210             Bragança              Bragança
# 25  2021.0         70903                Évora                Portel
# 26  2021.0         31406                Braga                Vizela
# 27  2021.0         91136               Guarda               Sabugal
# 28  2021.0        171230            Vila Real              Valpaços
# 29  2021.0        131141                Porto              Penafiel
# 30  2021.0         20522                 Beja                  Beja
# 31  2021.0        131701                Porto     Vila Nova de Gaia
# 32  2021.0         60406              Coimbra       Condeixa-a-Nova
# 33  2021.0         40218             Bragança              Bragança
# 34  2021.0         60704              Coimbra                 Lousã
# 35  2021.0         70524                Évora                 Évora
# 36  2021.0        320101  Ilha de Porto Santo           Porto Santo
# 37  2021.0        160915     Viana do Castelo      Viana do Castelo
# 38  2021.0         31013                Braga       Terras de Bouro
# 39  2021.0         90759               Guarda                Guarda
# 40  2021.0         50338       Castelo Branco               Covilhã
# 41  2021.0        111122               Lisboa                Sintra
# 42  2021.0        100618               Leiria      Caldas da Rainha
# 43  2021.0        180908                Viseu                 Nelas
# 44  2021.0        130906                Porto     Paços de Ferreira
# 45  2021.0         40534             Bragança  Macedo de Cavaleiros
# 46  2021.0        141904             Santarém          Torres Novas
# 47  2021.0         80808                 Faro                 Loulé
# 48  2021.0         40822             Bragança             Mogadouro
# 49  2021.0         30617                Braga             Esposende
#
#                                                Parish     Sex  \
# 0                                                Oura  Female
# 1                                          Girabolhos    Male
# 2                                       Santa Eulália    Male
# 3            União das freguesias da Ribeira do Neiva    Male
# 4                            Vilar do Torno e Alentém    Male
# 5      União das freguesias de Rio Torto e Lagarinhos  Female
# 6   União das freguesias de Custóias, Leça do Bali...    Male
# 7                                              Adaúfe    Male
# 8                                       Santo Emilião    Male
# 9                                  Sesimbra (Castelo)  Female
# 10                                        Pinhal Novo  Female
# 11            União das freguesias de Calvos e Frades  Female
# 12  União das freguesias de Valença, Cristelo Covo...  Female
# 13                                           Verdoejo    Male
# 14                                    Sazes do Lorvão    Male
# 15                                    Vilar de Mouros  Female
# 16                                              Longa  Female
# 17                                           Rio Frio  Female
# 18                                       Duas Igrejas    Male
# 19        União das freguesias de Carvoeira e Carmões  Female
# 20                                     Castelo Branco    Male
# 21                                  São João Baptista  Female
# 22            União das freguesias de Campo e Sobrado    Male
# 23  União das freguesias de Santa Clara-a-Nova e G...    Male
# 24                                           Coelhoso  Female
# 25                                     Monte do Trigo    Male
# 26                              Vizela (Santo Adrião)  Female
# 27                                    Vale de Espinho    Male
# 28                                      Veiga de Lila  Female
# 29                                    Guilhufe e Urrô  Female
# 30          União das freguesias de Salvada e Quintos  Female
# 31                                           Arcozelo  Female
# 32                                                Ega    Male
# 33                                             Gostei    Male
# 34                                            Serpins  Female
# 35  União das freguesias de Malagueira e Horta das...  Female
# 36                                        Porto Santo  Female
# 37                                           Lanheses  Female
# 38                                          Rio Caldo    Male
# 39                                 Jarmelo São Miguel    Male
# 40  União das freguesias de Vale Formoso e Aldeia ...  Female
# 41      União das freguesias de Agualva e Mira-Sintra  Female
# 42  União das freguesias de Caldas da Rainha - San...  Female
# 43                                       Lapa do Lobo    Male
# 44                                           Figueiró  Female
# 45                                     Vale de Prados    Male
# 46                                        Chancelaria  Female
# 47                               Loulé (São Clemente)    Male
# 48                                      Vale da Madre  Female
# 49              União das freguesias de Belinho e Mar  Female
#
#          Age_bracket  Population  Comments  Population_corrected
# 0       65 and older         100       NaN                   100
# 1    0 - 14 year old           5       NaN                     5
# 2    0 - 14 year old         137       NaN                   137
# 3    0 - 14 year old         203       NaN                   203
# 4   25 - 64 year old         346       NaN                   346
# 5    0 - 14 year old          26       NaN                    26
# 6   15 - 24 year old        2332       NaN                  2332
# 7   25 - 64 year old        1026       NaN                  1026
# 8   15 - 24 year old          47       NaN                    47
# 9   25 - 64 year old        5456       NaN                  5456
# 10  15 - 24 year old        1533       NaN                  1533
# 11  25 - 64 year old         188       NaN                   188
# 12   0 - 14 year old         333       NaN                   333
# 13  15 - 24 year old          16       NaN                    16
# 14      65 and older          98       NaN                    98
# 15      65 and older         111       NaN                   111
# 16   0 - 14 year old           4       NaN                     4
# 17  25 - 64 year old         105       NaN                   105
# 18      65 and older         132       NaN                   132
# 19  15 - 24 year old         110       NaN                   110
# 20  15 - 24 year old        1842       NaN                  1842
# 21      65 and older         196       NaN                   196
# 22      65 and older        1242       NaN                  1242
# 23  25 - 64 year old         184       NaN                   184
# 24  15 - 24 year old           6       NaN                     6
# 25  15 - 24 year old          65       NaN                    65
# 26   0 - 14 year old         122       NaN                   122
# 27  15 - 24 year old           8       NaN                     8
# 28  25 - 64 year old          55       NaN                    55
# 29  25 - 64 year old        1143       NaN                  1143
# 30  15 - 24 year old          55       NaN                    55
# 31  15 - 24 year old         751       NaN                   751
# 32      65 and older         324       NaN                   324
# 33   0 - 14 year old          13       NaN                    13
# 34  15 - 24 year old          79       NaN                    79
# 35  25 - 64 year old        6052       NaN                  6052
# 36      65 and older         539       NaN                   539
# 37      65 and older         291       NaN                   291
# 38   0 - 14 year old          39       NaN                    39
# 39  25 - 64 year old          62       NaN                    62
# 40   0 - 14 year old          32       NaN                    32
# 41      65 and older        4973       NaN                  4973
# 42  25 - 64 year old        3564       NaN                  3564
# 43   0 - 14 year old          29       NaN                    29
# 44   0 - 14 year old         165       NaN                   165
# 45  25 - 64 year old         110       NaN                   110
# 46  25 - 64 year old         339       NaN                   339
# 47      65 and older        1657       NaN                  1657
# 48   0 - 14 year old           7       NaN                     7
# 49  25 - 64 year old         798       NaN                   798

# %% [markdown]
# **Step 1.6.2** Use, again, the method `head` on dataframe `population` to look at the first 100 rows.

# %%
population.head(100)
# Out:
#       Year Location_Code       District Municipality  \
# 0   2021.0        170320      Vila Real       Chaves
# 1   2021.0         91205         Guarda         Seia
# 2   2021.0         10416         Aveiro       Arouca
# 3   2021.0         31360          Braga   Vila Verde
# 4   2021.0        130526          Porto      Lousada
# ..     ...           ...            ...          ...
# 95  2021.0        470101  Ilha do Faial        Horta
# 96  2021.0        140120       Santarém     Abrantes
# 97  2021.0        180409          Viseu      Cinfães
# 98  2021.0        110658         Lisboa       Lisboa
# 99  2021.0         90764         Guarda       Guarda
#
#                                                Parish     Sex  \
# 0                                                Oura  Female
# 1                                          Girabolhos    Male
# 2                                       Santa Eulália    Male
# 3            União das freguesias da Ribeira do Neiva    Male
# 4                            Vilar do Torno e Alentém    Male
# ..                                                ...     ...
# 95                                             Capelo    Male
# 96  União das freguesias de Abrantes (São Vicente ...  Female
# 97                                         Nespereira  Female
# 98                                              Belém  Female
# 99           União de freguesias de Pousade e Albardo    Male
#
#          Age_bracket  Population  Comments  Population_corrected
# 0       65 and older         100       NaN                   100
# 1    0 - 14 year old           5       NaN                     5
# 2    0 - 14 year old         137       NaN                   137
# 3    0 - 14 year old         203       NaN                   203
# 4   25 - 64 year old         346       NaN                   346
# ..               ...         ...       ...                   ...
# 95   0 - 14 year old          32       NaN                    32
# 96      65 and older        2193       NaN                  2193
# 97  25 - 64 year old         424       NaN                   424
# 98  15 - 24 year old         798       NaN                   798
# 99  25 - 64 year old          50       NaN                    50
#
# [100 rows x 10 columns]

# %% [markdown]
# That's not good. It seems that you wanted to see to many rows at once. While circumstancial, you might run in situations such as these. To circumvent it, you can use the following code to extend the viewing limits of pandas.

# %%
with pd.option_context('display.max_rows', None):
    display(population.head(100))
# Out:
#       Year Location_Code             District              Municipality  \
# 0   2021.0        170320            Vila Real                    Chaves
# 1   2021.0         91205               Guarda                      Seia
# 2   2021.0         10416               Aveiro                    Arouca
# 3   2021.0         31360                Braga                Vila Verde
# 4   2021.0        130526                Porto                   Lousada
# 5   2021.0         90628               Guarda                   Gouveia
# 6   2021.0        130811                Porto                Matosinhos
# 7   2021.0         30301                Braga                     Braga
# 8   2021.0         30922                Braga          Póvoa de Lanhoso
# 9   2021.0        151101              Setúbal                  Sesimbra
# 10  2021.0        150803              Setúbal                   Palmela
# 11  2021.0         30931                Braga          Póvoa de Lanhoso
# 12  2021.0        160820     Viana do Castelo                   Valença
# 13  2021.0        160816     Viana do Castelo                   Valença
# 14  2021.0         61310              Coimbra                  Penacova
# 15  2021.0        160218     Viana do Castelo         Arcos de Valdevez
# 16  2021.0        181908                Viseu                   Tabuaço
# 17  2021.0        160130     Viana do Castelo         Arcos de Valdevez
# 18  2021.0         40604             Bragança          Miranda do Douro
# 19  2021.0        111323               Lisboa             Torres Vedras
# 20  2021.0         50205       Castelo Branco            Castelo Branco
# 21  2021.0        120504           Portalegre           Castelo de Vide
# 22  2021.0        131506                Porto                   Valongo
# 23  2021.0         20210                 Beja                 Almodôvar
# 24  2021.0         40210             Bragança                  Bragança
# 25  2021.0         70903                Évora                    Portel
# 26  2021.0         31406                Braga                    Vizela
# 27  2021.0         91136               Guarda                   Sabugal
# 28  2021.0        171230            Vila Real                  Valpaços
# 29  2021.0        131141                Porto                  Penafiel
# 30  2021.0         20522                 Beja                      Beja
# 31  2021.0        131701                Porto         Vila Nova de Gaia
# 32  2021.0         60406              Coimbra           Condeixa-a-Nova
# 33  2021.0         40218             Bragança                  Bragança
# 34  2021.0         60704              Coimbra                     Lousã
# 35  2021.0         70524                Évora                     Évora
# 36  2021.0        320101  Ilha de Porto Santo               Porto Santo
# 37  2021.0        160915     Viana do Castelo          Viana do Castelo
# 38  2021.0         31013                Braga           Terras de Bouro
# 39  2021.0         90759               Guarda                    Guarda
# 40  2021.0         50338       Castelo Branco                   Covilhã
# 41  2021.0        111122               Lisboa                    Sintra
# 42  2021.0        100618               Leiria          Caldas da Rainha
# 43  2021.0        180908                Viseu                     Nelas
# 44  2021.0        130906                Porto         Paços de Ferreira
# 45  2021.0         40534             Bragança      Macedo de Cavaleiros
# 46  2021.0        141904             Santarém              Torres Novas
# 47  2021.0         80808                 Faro                     Loulé
# 48  2021.0         40822             Bragança                 Mogadouro
# 49  2021.0         30617                Braga                 Esposende
# 50  2021.0        131636                Porto             Vila do Conde
# 51  2021.0        171409            Vila Real                 Vila Real
# 52  2021.0        180412                Viseu                   Cinfães
# 53  2021.0        181615                Viseu          São Pedro do Sul
# 54  2021.0        181208                Viseu                  Penedono
# 55  2021.0        310310      Ilha da Madeira                   Funchal
# 56  2021.0         50416       Castelo Branco                    Fundão
# 57  2021.0        110618               Lisboa                    Lisboa
# 58  2021.0         10805               Aveiro                 Estarreja
# 59  2021.0        430201        Ilha Terceira  Vila da Praia da Vitória
# 60  2021.0         40727             Bragança                 Mirandela
# 61  2021.0         30212                Braga                  Barcelos
# 62  2021.0         71103                Évora     Reguengos de Monsaraz
# 63  2021.0        420103   Ilha de São Miguel                     Lagoa
# 64  2021.0         91032               Guarda                    Pinhel
# 65  2021.0        141809             Santarém                     Tomar
# 66  2021.0        180807                Viseu                  Mortágua
# 67  2021.0        310604      Ilha da Madeira               Porto Moniz
# 68  2021.0        101509               Leiria                    Pombal
# 69  2021.0         70522                Évora                     Évora
# 70  2021.0        310704      Ilha da Madeira             Ribeira Brava
# 71  2021.0         91032               Guarda                    Pinhel
# 72  2021.0        430118        Ilha Terceira         Angra do Heroísmo
# 73  2021.0         30806                Braga                 Guimarães
# 74  2021.0         50436       Castelo Branco                    Fundão
# 75  2021.0        160221     Viana do Castelo         Arcos de Valdevez
# 76  2021.0         30878                Braga                 Guimarães
# 77  2021.0         91304               Guarda                  Trancoso
# 78  2021.0        141634             Santarém                  Santarém
# 79  2021.0        182310                Viseu                     Viseu
# 80  2021.0        160323     Viana do Castelo                   Melgaço
# 81  2021.0         10936               Aveiro      Santa Maria da Feira
# 82  2021.0         30740                Braga                      Fafe
# 83  2021.0         30208                Braga                  Barcelos
# 84  2021.0         30224                Braga                  Barcelos
# 85  2021.0         80604                 Faro                     Lagoa
# 86  2021.0         31408                Braga                    Vizela
# 87  2021.0        100939               Leiria                    Leiria
# 88  2021.0        130515                Porto                   Lousada
# 89  2021.0        181902                Viseu                   Tabuaço
# 90  2021.0         30104                Braga                    Amares
# 91  2021.0        130224                Porto                     Baião
# 92  2021.0        170333            Vila Real                    Chaves
# 93  2021.0         30517                Braga         Celorico de Basto
# 94  2021.0         30290                Braga                  Barcelos
# 95  2021.0        470101        Ilha do Faial                     Horta
# 96  2021.0        140120             Santarém                  Abrantes
# 97  2021.0        180409                Viseu                   Cinfães
# 98  2021.0        110658               Lisboa                    Lisboa
# 99  2021.0         90764               Guarda                    Guarda
#
#                                                Parish     Sex  \
# 0                                                Oura  Female
# 1                                          Girabolhos    Male
# 2                                       Santa Eulália    Male
# 3            União das freguesias da Ribeira do Neiva    Male
# 4                            Vilar do Torno e Alentém    Male
# 5      União das freguesias de Rio Torto e Lagarinhos  Female
# 6   União das freguesias de Custóias, Leça do Bali...    Male
# 7                                              Adaúfe    Male
# 8                                       Santo Emilião    Male
# 9                                  Sesimbra (Castelo)  Female
# 10                                        Pinhal Novo  Female
# 11            União das freguesias de Calvos e Frades  Female
# 12  União das freguesias de Valença, Cristelo Covo...  Female
# 13                                           Verdoejo    Male
# 14                                    Sazes do Lorvão    Male
# 15                                    Vilar de Mouros  Female
# 16                                              Longa  Female
# 17                                           Rio Frio  Female
# 18                                       Duas Igrejas    Male
# 19        União das freguesias de Carvoeira e Carmões  Female
# 20                                     Castelo Branco    Male
# 21                                  São João Baptista  Female
# 22            União das freguesias de Campo e Sobrado    Male
# 23  União das freguesias de Santa Clara-a-Nova e G...    Male
# 24                                           Coelhoso  Female
# 25                                     Monte do Trigo    Male
# 26                              Vizela (Santo Adrião)  Female
# 27                                    Vale de Espinho    Male
# 28                                      Veiga de Lila  Female
# 29                                    Guilhufe e Urrô  Female
# 30          União das freguesias de Salvada e Quintos  Female
# 31                                           Arcozelo  Female
# 32                                                Ega    Male
# 33                                             Gostei    Male
# 34                                            Serpins  Female
# 35  União das freguesias de Malagueira e Horta das...  Female
# 36                                        Porto Santo  Female
# 37                                           Lanheses  Female
# 38                                          Rio Caldo    Male
# 39                                 Jarmelo São Miguel    Male
# 40  União das freguesias de Vale Formoso e Aldeia ...  Female
# 41      União das freguesias de Agualva e Mira-Sintra  Female
# 42  União das freguesias de Caldas da Rainha - San...  Female
# 43                                       Lapa do Lobo    Male
# 44                                           Figueiró  Female
# 45                                     Vale de Prados    Male
# 46                                        Chancelaria  Female
# 47                               Loulé (São Clemente)    Male
# 48                                      Vale da Madre  Female
# 49              União das freguesias de Belinho e Mar  Female
# 50      União das freguesias de Touguinha e Touguinhó    Male
# 51                                          Folhadela    Male
# 52                                  Santiago de Piães    Male
# 53                                           Serrazes    Male
# 54                                    Póvoa de Penela    Male
# 55                                       Funchal (Sé)    Male
# 56                                             Fatela    Male
# 57                                             Lumiar  Female
# 58                                           Pardilhó    Male
# 59                                            Agualva  Female
# 60                                    São Pedro Velho  Female
# 61                                           Balugães  Female
# 62                                           Monsaraz    Male
# 63                   Lagoa (Nossa Senhora do Rosário)    Male
# 64                                    Alto do Palurdo    Male
# 65                                            Paialvo  Female
# 66                                               Pala    Male
# 67                                             Seixal    Male
# 68                                             Pombal    Male
# 69  União das freguesias de Bacelo e Senhora da Saúde  Female
# 70                                              Tabua    Male
# 71                                    Alto do Palurdo  Female
# 72                                          Terra Chã    Male
# 73                                              Barco  Female
# 74  União das freguesias de Vale de Prazeres e Mat...    Male
# 75  União das freguesias de Arga (Baixo, Cima e Sã...  Female
# 76            União das freguesias de Atães e Rendufe  Female
# 77                                             Cogula  Female
# 78  União das freguesias de São Vicente do Paul e ...    Male
# 79                                               Cota  Female
# 80             União das freguesias de Vila e Roussas    Male
# 81  União de freguesias de São Miguel de Souto e M...    Male
# 82  União de freguesias de Ardegão, Arnozela e Sei...  Female
# 83                                            Alvelos  Female
# 84                                         Cossourado  Female
# 85                                            Porches  Female
# 86  União das freguesias de Caldas de Vizela (São ...  Female
# 87  União das freguesias de Santa Eufémia e Boa Vista    Male
# 88                                          Nevogilde  Female
# 89                                              Arcos  Female
# 90                                               Bico    Male
# 91  União das freguesias de Loivos da Ribeira e Tr...  Female
# 92                               São Pedro de Agostém  Female
# 93                                               Rego    Male
# 94      União das freguesias de Alheira e Igreja Nova  Female
# 95                                             Capelo    Male
# 96  União das freguesias de Abrantes (São Vicente ...  Female
# 97                                         Nespereira  Female
# 98                                              Belém  Female
# 99           União de freguesias de Pousade e Albardo    Male
#
#          Age_bracket  Population  Comments  Population_corrected
# 0       65 and older         100       NaN                   100
# 1    0 - 14 year old           5       NaN                     5
# 2    0 - 14 year old         137       NaN                   137
# 3    0 - 14 year old         203       NaN                   203
# 4   25 - 64 year old         346       NaN                   346
# 5    0 - 14 year old          26       NaN                    26
# 6   15 - 24 year old        2332       NaN                  2332
# 7   25 - 64 year old        1026       NaN                  1026
# 8   15 - 24 year old          47       NaN                    47
# 9   25 - 64 year old        5456       NaN                  5456
# 10  15 - 24 year old        1533       NaN                  1533
# 11  25 - 64 year old         188       NaN                   188
# 12   0 - 14 year old         333       NaN                   333
# 13  15 - 24 year old          16       NaN                    16
# 14      65 and older          98       NaN                    98
# 15      65 and older         111       NaN                   111
# 16   0 - 14 year old           4       NaN                     4
# 17  25 - 64 year old         105       NaN                   105
# 18      65 and older         132       NaN                   132
# 19  15 - 24 year old         110       NaN                   110
# 20  15 - 24 year old        1842       NaN                  1842
# 21      65 and older         196       NaN                   196
# 22      65 and older        1242       NaN                  1242
# 23  25 - 64 year old         184       NaN                   184
# 24  15 - 24 year old           6       NaN                     6
# 25  15 - 24 year old          65       NaN                    65
# 26   0 - 14 year old         122       NaN                   122
# 27  15 - 24 year old           8       NaN                     8
# 28  25 - 64 year old          55       NaN                    55
# 29  25 - 64 year old        1143       NaN                  1143
# 30  15 - 24 year old          55       NaN                    55
# 31  15 - 24 year old         751       NaN                   751
# 32      65 and older         324       NaN                   324
# 33   0 - 14 year old          13       NaN                    13
# 34  15 - 24 year old          79       NaN                    79
# 35  25 - 64 year old        6052       NaN                  6052
# 36      65 and older         539       NaN                   539
# 37      65 and older         291       NaN                   291
# 38   0 - 14 year old          39       NaN                    39
# 39  25 - 64 year old          62       NaN                    62
# 40   0 - 14 year old          32       NaN                    32
# 41      65 and older        4973       NaN                  4973
# 42  25 - 64 year old        3564       NaN                  3564
# 43   0 - 14 year old          29       NaN                    29
# 44   0 - 14 year old         165       NaN                   165
# 45  25 - 64 year old         110       NaN                   110
# 46  25 - 64 year old         339       NaN                   339
# 47      65 and older        1657       NaN                  1657
# 48   0 - 14 year old           7       NaN                     7
# 49  25 - 64 year old         798       NaN                   798
# 50  15 - 24 year old         170       NaN                   170
# 51  25 - 64 year old         546       NaN                   546
# 52   0 - 14 year old         117       NaN                   117
# 53      65 and older         134       NaN                   134
# 54  25 - 64 year old          76       NaN                    76
# 55  25 - 64 year old         711       NaN                   711
# 56  25 - 64 year old         116       NaN                   116
# 57      65 and older        5694       NaN                  5694
# 58      65 and older         400       NaN                   400
# 59  25 - 64 year old         347       NaN                   347
# 60      65 and older          87       NaN                    87
# 61      65 and older          88       NaN                    88
# 62  25 - 64 year old         174       NaN                   174
# 63  15 - 24 year old         323       NaN                   323
# 64  15 - 24 year old           8       NaN                     8
# 65  15 - 24 year old          99       NaN                    99
# 66  25 - 64 year old         213       NaN                   213
# 67  25 - 64 year old         168       NaN                   168
# 68  25 - 64 year old        4235       NaN                  4235
# 69  15 - 24 year old         882       NaN                   882
# 70  15 - 24 year old          69       NaN                    69
# 71   0 - 14 year old           2       NaN                     2
# 72  15 - 24 year old         203       NaN                   203
# 73   0 - 14 year old          96       NaN                    96
# 74   0 - 14 year old          30       NaN                    30
# 75      65 and older          54       NaN                    54
# 76   0 - 14 year old         170       NaN                   170
# 77   0 - 14 year old           6       NaN                     6
# 78      65 and older         374       NaN                   374
# 79  15 - 24 year old          24       NaN                    24
# 80  25 - 64 year old         532       NaN                   532
# 81   0 - 14 year old         374       NaN                   374
# 82  25 - 64 year old         264       NaN                   264
# 83  25 - 64 year old         566       NaN                   566
# 84  25 - 64 year old         204       NaN                   204
# 85  25 - 64 year old         599       NaN                   599
# 86  15 - 24 year old         588       NaN                   588
# 87      65 and older         458       NaN                   458
# 88  25 - 64 year old         740       NaN                   740
# 89  25 - 64 year old          46       NaN                    46
# 90  15 - 24 year old          54       NaN                    54
# 91   0 - 14 year old          30       NaN                    30
# 92  25 - 64 year old         338       NaN                   338
# 93   0 - 14 year old          69       NaN                    69
# 94   0 - 14 year old          85       NaN                    85
# 95   0 - 14 year old          32       NaN                    32
# 96      65 and older        2193       NaN                  2193
# 97  25 - 64 year old         424       NaN                   424
# 98  15 - 24 year old         798       NaN                   798
# 99  25 - 64 year old          50       NaN                    50

# %% [markdown]
# **Step 1.7** Use the method `tail` on dataframe `population` to look at the last rows of a dataframe (default = 5).

# %%
population.tail()
# Out:
#          Year Location_Code       District          Municipality  \
# 24723  2021.0         40542       Bragança  Macedo de Cavaleiros
# 24724  2021.0        140503       Santarém             Benavente
# 24725  2021.0        430101  Ilha Terceira     Angra do Heroísmo
# 24726  2021.0        171305      Vila Real  Vila Pouca de Aguiar
# 24727  2021.0        130526          Porto               Lousada
#
#                                                   Parish     Sex  \
# 24723  União das freguesias de Espadanedo, Edroso, Mu...    Male
# 24724                                      Santo Estêvão  Female
# 24725                                            Altares  Female
# 24726                                          Capeludos  Female
# 24727                           Vilar do Torno e Alentém    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 24723      65 and older          76       NaN                    76
# 24724   0 - 14 year old         124       NaN                   124
# 24725  25 - 64 year old         235       NaN                   235
# 24726   0 - 14 year old           5       NaN                     5
# 24727  15 - 24 year old          68       NaN                    68

# %% [markdown]
# **Step 1.7.1** Use, again, the method `tail` on dataframe `population` to look at the last 50 rows.

# %%
population.tail(50)
# Out:
#          Year Location_Code          District                Municipality  \
# 24678  2021.0        480102   Ilha das Flores            Lajes das Flores
# 24679  2021.0        181111             Viseu          Penalva do Castelo
# 24680  2021.0         70304             Évora                       Borba
# 24681  2021.0        181917             Viseu                     Tabuaço
# 24682  2021.0        151302           Setúbal                       Sines
# 24683  2021.0         40119          Bragança             Alfândega da Fé
# 24684  2021.0         30322             Braga                       Braga
# 24685  2021.0         11706            Aveiro              Sever do Vouga
# 24686  2021.0         50901    Castelo Branco                       Sertã
# 24687  2021.0         80903              Faro                   Monchique
# 24688  2021.0         90721            Guarda                      Guarda
# 24689  2021.0         30404             Braga         Cabeceiras de Basto
# 24690  2021.0         61302           Coimbra                    Penacova
# 24691  2021.0        131210             Porto                       Porto
# 24692  2021.0         90518            Guarda          Fornos de Algodres
# 24693  2021.0         50521    Castelo Branco               Idanha-a-Nova
# 24694  2021.0        160209  Viana do Castelo           Arcos de Valdevez
# 24695  2021.0         61619           Coimbra                       Tábua
# 24696  2021.0        180707             Viseu           Moimenta da Beira
# 24697  2021.0        111413            Lisboa         Vila Franca de Xira
# 24698  2021.0        151210           Setúbal                     Setúbal
# 24699  2021.0        121210        Portalegre                        Nisa
# 24700  2021.0         50322    Castelo Branco                     Covilhã
# 24701  2021.0         70201             Évora                   Arraiolos
# 24702  2021.0        182012             Viseu                     Tarouca
# 24703  2021.0         10919            Aveiro        Santa Maria da Feira
# 24704  2021.0        181811             Viseu                 Sernancelhe
# 24705  2021.0         81603              Faro  Vila Real de Santo António
# 24706  2021.0         40520          Bragança        Macedo de Cavaleiros
# 24707  2021.0         90628            Guarda                     Gouveia
# 24708  2021.0        171220         Vila Real                    Valpaços
# 24709  2021.0        180323             Viseu                Castro Daire
# 24710  2021.0         50435    Castelo Branco                      Fundão
# 24711  2021.0         40323          Bragança        Carrazeda de Ansiães
# 24712  2021.0         11109            Aveiro                    Mealhada
# 24713  2021.0        121308        Portalegre                Ponte de Sor
# 24714  2021.0         40708          Bragança                   Mirandela
# 24715  2021.0        160802  Viana do Castelo                     Valença
# 24716  2021.0         81306              Faro                      Silves
# 24717  2021.0        181202             Viseu                    Penedono
# 24718  2021.0         30931             Braga            Póvoa de Lanhoso
# 24719  2021.0        0302FB             Braga                    Barcelos
# 24720  2021.0        181313             Viseu                     Resende
# 24721  2021.0         91028            Guarda                      Pinhel
# 24722  2021.0         60115           Coimbra                     Arganil
# 24723  2021.0         40542          Bragança        Macedo de Cavaleiros
# 24724  2021.0        140503          Santarém                   Benavente
# 24725  2021.0        430101     Ilha Terceira           Angra do Heroísmo
# 24726  2021.0        171305         Vila Real        Vila Pouca de Aguiar
# 24727  2021.0        130526             Porto                     Lousada
#
#                                                   Parish     Sex  \
# 24678                                          Fajãzinha    Male
# 24679                                            Sezures  Female
# 24680                             Borba (São Bartolomeu)    Male
# 24681                                   Valença do Douro    Male
# 24682                                         Porto Covo  Female
# 24683                                         Vilarelhos  Female
# 24684                                              Lamas    Male
# 24685                                     Sever do Vouga    Male
# 24686                                           Cabeçudo  Female
# 24687                                          Monchique    Male
# 24688                                      Gonçalo Bocas    Male
# 24689                                              Basto  Female
# 24690                                 Figueira de Lorvão  Female
# 24691                                           Paranhos    Male
# 24692  União das freguesias de Juncais, Vila Ruiva e ...  Female
# 24693          União das freguesias de Zebreira e Segura    Male
# 24694                                                Dem  Female
# 24695  União das freguesias de Pinheiro de Coja e Med...  Female
# 24696                                              Caria  Female
# 24697  União das freguesias de Alverca do Ribatejo e ...  Female
# 24698  União das freguesias de Setúbal (São Julião, N...  Female
# 24699                                             Tolosa  Female
# 24700                               Sobral de São Miguel  Female
# 24701                                          Arraiolos    Male
# 24702  União das freguesias de Granja Nova e Vila Chã...    Male
# 24703                                   Paços de Brandão  Female
# 24704                                             Lamosa    Male
# 24705                                        Monte Gordo    Male
# 24706                               Macedo de Cavaleiros    Male
# 24707     União das freguesias de Rio Torto e Lagarinhos    Male
# 24708                                        Santa Valha    Male
# 24709  União das freguesias de Mamouros, Alva e Ribolhos  Female
# 24710  União das freguesias de Póvoa de Atalaia e Ata...  Female
# 24711  União das freguesias de Lavandeira, Beira Gran...  Female
# 24712  União das freguesias da Mealhada, Ventosa do B...  Female
# 24713  União das freguesias de Ponte de Sor, Tramaga ...    Male
# 24714                                              Bouça  Female
# 24715                                             Boivão  Female
# 24716                                São Marcos da Serra  Female
# 24717                                            Beselga    Male
# 24718            União das freguesias de Calvos e Frades    Male
# 24719         União das freguesias de Negreiros e Chavão  Female
# 24720                               São João de Fontoura    Male
# 24721             Agregação das freguesias Sul de Pinhel  Female
# 24722                                            Sarzedo  Female
# 24723  União das freguesias de Espadanedo, Edroso, Mu...    Male
# 24724                                      Santo Estêvão  Female
# 24725                                            Altares  Female
# 24726                                          Capeludos  Female
# 24727                           Vilar do Torno e Alentém    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 24678  15 - 24 year old           2       NaN                     2
# 24679  15 - 24 year old          30       NaN                    30
# 24680  25 - 64 year old         132       NaN                   132
# 24681      65 and older          37       NaN                    37
# 24682   0 - 14 year old          68       NaN                    68
# 24683   0 - 14 year old           9       NaN                     9
# 24684   0 - 14 year old          67       NaN                    67
# 24685      65 and older         303       NaN                   303
# 24686  25 - 64 year old         237       NaN                   237
# 24687      65 and older         670       NaN                   670
# 24688  25 - 64 year old          55       NaN                    55
# 24689      65 and older          67       NaN                    67
# 24690   0 - 14 year old         100       NaN                   100
# 24691      65 and older        4505       NaN                  4505
# 24692      65 and older         143       NaN                   143
# 24693  25 - 64 year old         214       NaN                   214
# 24694      65 and older          65       NaN                    65
# 24695   0 - 14 year old          19       NaN                    19
# 24696   0 - 14 year old          15       NaN                    15
# 24697  15 - 24 year old        1841       NaN                  1841
# 24698  25 - 64 year old       10089       NaN                 10089
# 24699   0 - 14 year old          33       NaN                    33
# 24700  25 - 64 year old          49       NaN                    49
# 24701      65 and older         330       NaN                   330
# 24702  25 - 64 year old          97       NaN                    97
# 24703   0 - 14 year old         238       NaN                   238
# 24704   0 - 14 year old           8       NaN                     8
# 24705  25 - 64 year old         829       NaN                   829
# 24706      65 and older         636       NaN                   636
# 24707   0 - 14 year old          34       NaN                    34
# 24708  25 - 64 year old          71       NaN                    71
# 24709   0 - 14 year old          62       NaN                    62
# 24710  25 - 64 year old         218       NaN                   218
# 24711  15 - 24 year old          13       NaN                    13
# 24712  15 - 24 year old         309       NaN                   309
# 24713  15 - 24 year old         526       NaN                   526
# 24714      65 and older          48       NaN                    48
# 24715  15 - 24 year old          10       NaN                    10
# 24716      65 and older         225       NaN                   225
# 24717  15 - 24 year old          11       NaN                    11
# 24718      65 and older          86       NaN                    86
# 24719   0 - 14 year old         147       NaN                   147
# 24720   0 - 14 year old          30       NaN                    30
# 24721  15 - 24 year old          14       NaN                    14
# 24722   0 - 14 year old          31       NaN                    31
# 24723      65 and older          76       NaN                    76
# 24724   0 - 14 year old         124       NaN                   124
# 24725  25 - 64 year old         235       NaN                   235
# 24726   0 - 14 year old           5       NaN                     5
# 24727  15 - 24 year old          68       NaN                    68

# %% [markdown]
# **Step 1.7.2** Use, again, the method `tail` on dataframe `population` to look at the last 100 rows.

# %%
population.tail(100)
# Out:
#          Year Location_Code        District          Municipality  \
# 24628  2021.0         90210          Guarda               Almeida
# 24629  2021.0         50431  Castelo Branco                Fundão
# 24630  2021.0        180417           Viseu               Cinfães
# 24631  2021.0         30838           Braga             Guimarães
# 24632  2021.0        110109          Lisboa              Alenquer
# ...       ...           ...             ...                   ...
# 24723  2021.0         40542        Bragança  Macedo de Cavaleiros
# 24724  2021.0        140503        Santarém             Benavente
# 24725  2021.0        430101   Ilha Terceira     Angra do Heroísmo
# 24726  2021.0        171305       Vila Real  Vila Pouca de Aguiar
# 24727  2021.0        130526           Porto               Lousada
#
#                                                   Parish     Sex  \
# 24628                                             Freixo    Male
# 24629                                            Enxames    Male
# 24630                                           Travanca    Male
# 24631                                              Ponte    Male
# 24632                                                Ota    Male
# ...                                                  ...     ...
# 24723  União das freguesias de Espadanedo, Edroso, Mu...    Male
# 24724                                      Santo Estêvão  Female
# 24725                                            Altares  Female
# 24726                                          Capeludos  Female
# 24727                           Vilar do Torno e Alentém    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 24628      65 and older          23       NaN                    23
# 24629  25 - 64 year old          99       NaN                    99
# 24630  25 - 64 year old         180       NaN                   180
# 24631      65 and older         513       NaN                   513
# 24632   0 - 14 year old          93       NaN                    93
# ...                 ...         ...       ...                   ...
# 24723      65 and older          76       NaN                    76
# 24724   0 - 14 year old         124       NaN                   124
# 24725  25 - 64 year old         235       NaN                   235
# 24726   0 - 14 year old           5       NaN                     5
# 24727  15 - 24 year old          68       NaN                    68
#
# [100 rows x 10 columns]

# %% [markdown]
# A simple, yet less discussed form at looking at the dataset using jupyter notebooks is by just the dataset outright. The dataset will be presented in a truncated format, showing the first and the last 5 rows.

# %%
population
# Out:
#          Year Location_Code       District          Municipality  \
# 0      2021.0        170320      Vila Real                Chaves
# 1      2021.0         91205         Guarda                  Seia
# 2      2021.0         10416         Aveiro                Arouca
# 3      2021.0         31360          Braga            Vila Verde
# 4      2021.0        130526          Porto               Lousada
# ...       ...           ...            ...                   ...
# 24723  2021.0         40542       Bragança  Macedo de Cavaleiros
# 24724  2021.0        140503       Santarém             Benavente
# 24725  2021.0        430101  Ilha Terceira     Angra do Heroísmo
# 24726  2021.0        171305      Vila Real  Vila Pouca de Aguiar
# 24727  2021.0        130526          Porto               Lousada
#
#                                                   Parish     Sex  \
# 0                                                   Oura  Female
# 1                                             Girabolhos    Male
# 2                                          Santa Eulália    Male
# 3               União das freguesias da Ribeira do Neiva    Male
# 4                               Vilar do Torno e Alentém    Male
# ...                                                  ...     ...
# 24723  União das freguesias de Espadanedo, Edroso, Mu...    Male
# 24724                                      Santo Estêvão  Female
# 24725                                            Altares  Female
# 24726                                          Capeludos  Female
# 24727                           Vilar do Torno e Alentém    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 0          65 and older         100       NaN                   100
# 1       0 - 14 year old           5       NaN                     5
# 2       0 - 14 year old         137       NaN                   137
# 3       0 - 14 year old         203       NaN                   203
# 4      25 - 64 year old         346       NaN                   346
# ...                 ...         ...       ...                   ...
# 24723      65 and older          76       NaN                    76
# 24724   0 - 14 year old         124       NaN                   124
# 24725  25 - 64 year old         235       NaN                   235
# 24726   0 - 14 year old           5       NaN                     5
# 24727  15 - 24 year old          68       NaN                    68
#
# [24728 rows x 10 columns]

# %% [markdown]
# If you look at the rows, it is clear that the rows do not seem to follow any particular order. We can, however, seamlessly rearrange the order of the rows using the method `sort_values()`. More information on this method can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html).
#
# **Step 1.8** Sort dataframe `population` by the column `District` in ascending order<br>
# **Note**: Sorting text will be alphabetical, however bear in mind that having accents or special characters will affect the order. For example, `é` will be sorted after `z`.

# %%
population.sort_values(
    by="District",
    ascending=True
)
# Out:
#          Year Location_Code District         Municipality  \
# 21545  2021.0         10517   Aveiro               Aveiro
# 10318  2021.0         10610   Aveiro     Castelo de Paiva
# 994    2021.0         11509   Aveiro                 Ovar
# 14124  2021.0         11305   Aveiro  Oliveira de Azeméis
# 23031  2021.0         10121   Aveiro               Águeda
# ...       ...           ...      ...                  ...
# 8986   2021.0         70509    Évora                Évora
# 21953  2021.0         70304    Évora                Borba
# 4994   2021.0         70906    Évora               Portel
# 17157  2021.0         71404    Évora          Vila Viçosa
# 11436  2021.0         70506    Évora                Évora
#
#                                                   Parish     Sex  \
# 21545         União das freguesias de Glória e Vera Cruz  Female
# 10318  União das freguesias de Raiva, Pedorido e Paraíso  Female
# 994    União das freguesias de Ovar, São João, Arada ...    Male
# 14124                                 Macieira de Sarnes    Male
# 23031          União das freguesias de Águeda e Borralha  Female
# ...                                                  ...     ...
# 8986                               São Miguel de Machede  Female
# 21953                             Borba (São Bartolomeu)    Male
# 4994                                             Santana    Male
# 17157                                            Pardais    Male
# 11436                                  São Bento do Mato  Female
#
#             Age_bracket  Population  Comments  Population_corrected
# 21545  25 - 64 year old        6328       NaN                  6328
# 10318  25 - 64 year old        1152       NaN                  1152
# 994    15 - 24 year old        1646       NaN                  1646
# 14124   0 - 14 year old         109       NaN                   109
# 23031      65 and older        1793       NaN                  1793
# ...                 ...         ...       ...                   ...
# 8986   25 - 64 year old         180       NaN                   180
# 21953   0 - 14 year old          24       NaN                    24
# 4994       65 and older          56       NaN                    56
# 17157      65 and older          48       NaN                    48
# 11436  15 - 24 year old          39       NaN                    39
#
# [24728 rows x 10 columns]

# %% [markdown]
# Doing this, however, will just create view of the sorted dataset. However, the original dataset will remain unchanged.
#
# **Step 1.8.1** Call the dataset population to see if your sorting worked

# %%
population
# Out:
#          Year Location_Code       District          Municipality  \
# 0      2021.0        170320      Vila Real                Chaves
# 1      2021.0         91205         Guarda                  Seia
# 2      2021.0         10416         Aveiro                Arouca
# 3      2021.0         31360          Braga            Vila Verde
# 4      2021.0        130526          Porto               Lousada
# ...       ...           ...            ...                   ...
# 24723  2021.0         40542       Bragança  Macedo de Cavaleiros
# 24724  2021.0        140503       Santarém             Benavente
# 24725  2021.0        430101  Ilha Terceira     Angra do Heroísmo
# 24726  2021.0        171305      Vila Real  Vila Pouca de Aguiar
# 24727  2021.0        130526          Porto               Lousada
#
#                                                   Parish     Sex  \
# 0                                                   Oura  Female
# 1                                             Girabolhos    Male
# 2                                          Santa Eulália    Male
# 3               União das freguesias da Ribeira do Neiva    Male
# 4                               Vilar do Torno e Alentém    Male
# ...                                                  ...     ...
# 24723  União das freguesias de Espadanedo, Edroso, Mu...    Male
# 24724                                      Santo Estêvão  Female
# 24725                                            Altares  Female
# 24726                                          Capeludos  Female
# 24727                           Vilar do Torno e Alentém    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 0          65 and older         100       NaN                   100
# 1       0 - 14 year old           5       NaN                     5
# 2       0 - 14 year old         137       NaN                   137
# 3       0 - 14 year old         203       NaN                   203
# 4      25 - 64 year old         346       NaN                   346
# ...                 ...         ...       ...                   ...
# 24723      65 and older          76       NaN                    76
# 24724   0 - 14 year old         124       NaN                   124
# 24725  25 - 64 year old         235       NaN                   235
# 24726   0 - 14 year old           5       NaN                     5
# 24727  15 - 24 year old          68       NaN                    68
#
# [24728 rows x 10 columns]

# %% [markdown]
# **Step 1.8.2** Try to sort the dataframe population, now in descending order on columns `District`, `Municipality` and `Parish`. Make sure that you leave set the parameter `inplace = True`. Then, call the dataset to check whether the sorting was successful.

# %%
#sorting
population.sort_values(
    by=["District", "Municipality", "Parish"],
    ascending=False,
    inplace=True
)
#checking changes
population
# Out:
#          Year Location_Code District        Municipality  \
# 3232   2021.0         70523    Évora               Évora
# 7672   2021.0         70523    Évora               Évora
# 13912  2021.0         70523    Évora               Évora
# 14498  2021.0         70523    Évora               Évora
# 16065  2021.0         70523    Évora               Évora
# ...       ...           ...      ...                 ...
# 4904   2021.0         10209   Aveiro  Albergaria-a-Velha
# 14888  2021.0         10209   Aveiro  Albergaria-a-Velha
# 15395  2021.0         10209   Aveiro  Albergaria-a-Velha
# 21325  2021.0         10209   Aveiro  Albergaria-a-Velha
# 22975  2021.0         10209   Aveiro  Albergaria-a-Velha
#
#                                                   Parish     Sex  \
# 3232   União das freguesias de Évora (São Mamede, Sé,...  Female
# 7672   União das freguesias de Évora (São Mamede, Sé,...    Male
# 13912  União das freguesias de Évora (São Mamede, Sé,...    Male
# 14498  União das freguesias de Évora (São Mamede, Sé,...  Female
# 16065  União das freguesias de Évora (São Mamede, Sé,...    Male
# ...                                                  ...     ...
# 4904                       Albergaria-a-Velha e Valmaior  Female
# 14888                      Albergaria-a-Velha e Valmaior  Female
# 15395                      Albergaria-a-Velha e Valmaior    Male
# 21325                      Albergaria-a-Velha e Valmaior    Male
# 22975                      Albergaria-a-Velha e Valmaior  Female
#
#             Age_bracket  Population  Comments  Population_corrected
# 3232   15 - 24 year old         212       NaN                   212
# 7672       65 and older         430       NaN                   430
# 13912   0 - 14 year old         265       NaN                   265
# 14498      65 and older         771       NaN                   771
# 16065  25 - 64 year old        1052       NaN                  1052
# ...                 ...         ...       ...                   ...
# 4904   15 - 24 year old         576       NaN                   576
# 14888   0 - 14 year old         777       NaN                   777
# 15395  25 - 64 year old        2941       NaN                  2941
# 21325  15 - 24 year old         625       NaN                   625
# 22975  25 - 64 year old        3148       NaN                  3148
#
# [24728 rows x 10 columns]

# %% [markdown]
# Another important method in EDA is `info()`. It gives us the number of non-null values in each column and the data type of each column. This is useful to check if there are any missing values in the dataset.
#
# **Step 1.9** Use the method `info()` on `population`. Are there any columns with a datatype that are nonsensical? Moreover, is there any column with missing values? Write your answer in the markdown cell below.

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24728 entries, 3232 to 22975
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  24728 non-null  float64
#  1   Location_Code         24728 non-null  object
#  2   District              24728 non-null  object
#  3   Municipality          24728 non-null  object
#  4   Parish                24728 non-null  object
#  5   Sex                   24728 non-null  object
#  6   Age_bracket           24728 non-null  object
#  7   Population            24728 non-null  int64
#  8   Comments              0 non-null      float64
#  9   Population_corrected  24728 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# **Answer**:

# %%
population.isna().sum() # Better way to see missing values....
# Out:
# Year                        0
# Location_Code               0
# District                    0
# Municipality                0
# Parish                      0
# Sex                         0
# Age_bracket                 0
# Population                  0
# Comments                24728
# Population_corrected        0
# dtype: int64

# %% [markdown]
# #### Descriptive statistics<a class="anchor" id="P1.3"></a>
#
# Looking at individual rows can only tell so much, so it is useful that we have some methods that allow us to get a better sense of the data. For example, we could be interested in understanding how the population is distributed and for that, we can statistical variables such as the mean, median, standard deviation, etc.
#
# **Step 1.9** Obtain some descriptive statistics of column `Population` (mean, median, first quartile and third quartile)
#
# **Step 1.9.1** Calculate the mean of column `Population`

# %%
population['Population'].mean()
# Out:
# 417.9555160142349

# %% [markdown]
# **Step 1.9.2** Calculate the median of column `Population`

# %%
population.Population.median()
# Out:
# 108.0

# %% [markdown]
# **Step 1.9.2** Calculate the first quartile of column `Population`.
# **Note:** Use the `quantile()` method. You can check how it works [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.quantile.html).

# %%
population.Population.quantile(.25)
# Out:
# 41.0

# %% [markdown]
# **Step 1.9.3** Calculate the third quartile of column `Population`.

# %%
population.Population.quantile(.75)
# Out:
# 304.0

# %% [markdown]
# Calculating statistical properties of one, or more, variables is important in many regards. `pandas` has a very helpful method that will allow you to obtain the most relevant descriptive statistics for any variable in `describe()`.
#
# **Step 1.9.5** Use the `describe()` method to obtain the descriptive statistics for the numerical variables of dataset `population`
# **Note**: Depending on your preference, you may prefer to look at the resulting dataframe in its transposed form using `describe().T`

# %%
population.describe().T
# Out:
#                         count         mean          std     min     25%  \
# Year                  24728.0  2021.000000     0.000000  2021.0  2021.0
# Population            24728.0   417.955516  1134.569287     0.0    41.0
# Comments                  0.0          NaN          NaN     NaN     NaN
# Population_corrected  24728.0   417.955516  1134.569287     0.0    41.0
#
#                          50%     75%      max
# Year                  2021.0  2021.0   2021.0
# Population             108.0   304.0  20301.0
# Comments                 NaN     NaN      NaN
# Population_corrected   108.0   304.0  20301.0

# %%
population.describe(include='O').T
# Out:
#                count unique               top   freq
# Location_Code  24728   3091             70523      8
# District       24728     29             Braga   2776
# Municipality   24728    306          Barcelos    488
# Parish         24728   2873          Pinheiro     48
# Sex            24728      2            Female  12364
# Age_bracket    24728      4  15 - 24 year old   6182

# %%
population.describe(include='all').T
# kind of questionable...
# Out:
#                         count unique               top   freq        mean  \
# Year                  24728.0    NaN               NaN    NaN      2021.0
# Location_Code           24728   3091             70523      8         NaN
# District                24728     29             Braga   2776         NaN
# Municipality            24728    306          Barcelos    488         NaN
# Parish                  24728   2873          Pinheiro     48         NaN
# Sex                     24728      2            Female  12364         NaN
# Age_bracket             24728      4  15 - 24 year old   6182         NaN
# Population            24728.0    NaN               NaN    NaN  417.955516
# Comments                  0.0    NaN               NaN    NaN         NaN
# Population_corrected  24728.0    NaN               NaN    NaN  417.955516
#
#                               std     min     25%     50%     75%      max
# Year                          0.0  2021.0  2021.0  2021.0  2021.0   2021.0
# Location_Code                 NaN     NaN     NaN     NaN     NaN      NaN
# District                      NaN     NaN     NaN     NaN     NaN      NaN
# Municipality                  NaN     NaN     NaN     NaN     NaN      NaN
# Parish                        NaN     NaN     NaN     NaN     NaN      NaN
# Sex                           NaN     NaN     NaN     NaN     NaN      NaN
# Age_bracket                   NaN     NaN     NaN     NaN     NaN      NaN
# Population            1134.569287     0.0    41.0   108.0   304.0  20301.0
# Comments                      NaN     NaN     NaN     NaN     NaN      NaN
# Population_corrected  1134.569287     0.0    41.0   108.0   304.0  20301.0

# %% [markdown]
# Categorical variables also have their own methods. For example, you may want to know what is the `District` that appears more often or how many parishes it has.
#
# **Step 1.10.1** Use the method `mode()` on the `District` column to find the most common district in the dataset.

# %%
population['District'].mode()
# Out:
# 0    Braga
# Name: District, dtype: object

# %% [markdown]
# **Step 1.10.2** Use the method `describe(include = 'O')` to find relevant statistics for the `object` columns in dataframe `population`

# %%
population.describe(include = 'O')
# Out:
#        Location_Code District Municipality    Parish     Sex       Age_bracket
# count          24728    24728        24728     24728   24728             24728
# unique          3091       29          306      2873       2                 4
# top            70523    Braga     Barcelos  Pinheiro  Female  15 - 24 year old
# freq               8     2776          488        48   12364              6182

# %% [markdown]
# **Step 1.10.3** Use the method `value_counts()` to count the number of rows that refer to each district.

# %%
#CODE HERE
population.District.value_counts()
# Out:
# District
# Braga                  2776
# Viseu                  2216
# Porto                  1944
# Guarda                 1936
# Bragança               1808
# Viana do Castelo       1664
# Vila Real              1576
# Coimbra                1240
# Aveiro                 1168
# Santarém               1128
# Lisboa                 1072
# Castelo Branco          960
# Leiria                  880
# Beja                    600
# Évora                   552
# Portalegre              552
# Faro                    536
# Ilha de São Miguel      512
# Setúbal                 440
# Ilha da Madeira         424
# Ilha Terceira           240
# Ilha do Pico            136
# Ilha do Faial           104
# Ilha das Flores          88
# Ilha de São Jorge        88
# Ilha de Santa Maria      40
# Ilha da Graciosa         32
# Ilha de Porto Santo       8
# Ilha do Corvo             8
# Name: count, dtype: int64

# %% [markdown]
# Is this the number of parishes per district?
#
# **Step 1.10.3** Validate the claim that each parish is represented by 8 rows using value counts.<br>
# **Hint**: You can use value_counts on multiple columns simultaneously

# %%
population[['District', 'Municipality', 'Parish']].value_counts()
# Out:
# District  Municipality        Parish
# Aveiro    Albergaria-a-Velha  Albergaria-a-Velha e Valmaior                                              8
# Porto     Paredes             Vandoma                                                                    8
#           Penafiel            Guilhufe e Urrô                                                            8
#                               Irivo                                                                      8
#                               Lagares e Figueira                                                         8
#                                                                                                         ..
# Coimbra   Penacova            Carvalho                                                                   8
#                               Figueira de Lorvão                                                         8
#                               Lorvão                                                                     8
#                               Penacova                                                                   8
# Évora     Évora               União das freguesias de Évora (São Mamede, Sé, São Pedro e Santo Antão)    8
# Name: count, Length: 3091, dtype: int64

# %% [markdown]
# **Step 1.10.4** Now that we confirmed that each parish is represented by 8 rows, use `value_counts` to obtain the number of parishes in each district<br>
# **Hint** Recall that you can apply mathematical operations to pandas series

# %%
population.District.value_counts()/8
# Out:
# District
# Braga                  347.0
# Viseu                  277.0
# Porto                  243.0
# Guarda                 242.0
# Bragança               226.0
# Viana do Castelo       208.0
# Vila Real              197.0
# Coimbra                155.0
# Aveiro                 146.0
# Santarém               141.0
# Lisboa                 134.0
# Castelo Branco         120.0
# Leiria                 110.0
# Beja                    75.0
# Évora                   69.0
# Portalegre              69.0
# Faro                    67.0
# Ilha de São Miguel      64.0
# Setúbal                 55.0
# Ilha da Madeira         53.0
# Ilha Terceira           30.0
# Ilha do Pico            17.0
# Ilha do Faial           13.0
# Ilha das Flores         11.0
# Ilha de São Jorge       11.0
# Ilha de Santa Maria      5.0
# Ilha da Graciosa         4.0
# Ilha de Porto Santo      1.0
# Ilha do Corvo            1.0
# Name: count, dtype: float64

# %% [markdown]
# A final note on `describe`. It is possible to obtain the aggregate basic statistics for both numerical and object variables using `include = 'all'`. For each dtype, the method will automatically detect which descriptive statistics to compute and assume the nonsensical statistics to be NaNs. See the example below:

# %%
population.describe(include='all').T
# Out:
#                         count unique               top   freq        mean  \
# Year                  24728.0    NaN               NaN    NaN      2021.0
# Location_Code           24728   3091             70523      8         NaN
# District                24728     29             Braga   2776         NaN
# Municipality            24728    306          Barcelos    488         NaN
# Parish                  24728   2873          Pinheiro     48         NaN
# Sex                     24728      2            Female  12364         NaN
# Age_bracket             24728      4  15 - 24 year old   6182         NaN
# Population            24728.0    NaN               NaN    NaN  417.955516
# Comments                  0.0    NaN               NaN    NaN         NaN
# Population_corrected  24728.0    NaN               NaN    NaN  417.955516
#
#                               std     min     25%     50%     75%      max
# Year                          0.0  2021.0  2021.0  2021.0  2021.0   2021.0
# Location_Code                 NaN     NaN     NaN     NaN     NaN      NaN
# District                      NaN     NaN     NaN     NaN     NaN      NaN
# Municipality                  NaN     NaN     NaN     NaN     NaN      NaN
# Parish                        NaN     NaN     NaN     NaN     NaN      NaN
# Sex                           NaN     NaN     NaN     NaN     NaN      NaN
# Age_bracket                   NaN     NaN     NaN     NaN     NaN      NaN
# Population            1134.569287     0.0    41.0   108.0   304.0  20301.0
# Comments                      NaN     NaN     NaN     NaN     NaN      NaN
# Population_corrected  1134.569287     0.0    41.0   108.0   304.0  20301.0

# %% [markdown]
# ### <font color='#BFD72F'>2. Grouping and Aggregation</font> <a class="anchor" id="P2"></a>
#   [Back to TOC](#toc)
#
#   In this section, we will shift our attention to grouping data and aggregate statistical measures. In particular, we will cover the flexible method that is `groupby()`. More info in this method [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html). It is really important to bear in mind that <b>the output of `groupby()` can either be a *pandas* series or *pandas* dataframe</b>. This means that we can apply all the methods that are applicable to those data structures that we have covered thus far.
#
#   Taking into consideration our data, we may want to verify what is the total population per district.
#
#   **Step 2.1** Use `groupby()` to get the `sum` of the populain every numerical column per district.

# %%
population.groupby('District').sum(numeric_only=True) #numeric_only set to True because of coming changes to groupby()
# Out:
#                           Year  Population  Comments  Population_corrected
# District
# Aveiro               2360528.0      692925       0.0                692925
# Beja                 1212600.0      144401       0.0                144401
# Braga                5610296.0      846293       0.0                846293
# Bragança             3653968.0      122804       0.0                122804
# Castelo Branco       1940160.0      177962       0.0                177962
# Coimbra              2506040.0      408551       0.0                408551
# Faro                 1083256.0      467343       0.0                467343
# Guarda               3912656.0      142974       0.0                142974
# Ilha Terceira         485040.0       53234       0.0                 53234
# Ilha da Graciosa       64672.0        4090       0.0                  4090
# Ilha da Madeira       856904.0      245595       0.0                245595
# Ilha das Flores       177848.0        3428       0.0                  3428
# Ilha de Porto Santo    16168.0        5149       0.0                  5149
# Ilha de Santa Maria    80840.0        5406       0.0                  5406
# Ilha de São Jorge     177848.0        8373       0.0                  8373
# Ilha de São Miguel   1034752.0      133288       0.0                133288
# Ilha do Corvo          16168.0         384       0.0                   384
# Ilha do Faial         210184.0       14331       0.0                 14331
# Ilha do Pico          274856.0       13879       0.0                 13879
# Leiria               1778480.0      458605       0.0                458605
# Lisboa               2166512.0     2275385       0.0               2275385
# Portalegre           1115592.0      104923       0.0                104923
# Porto                3928824.0     1785405       0.0               1785405
# Santarém             2279688.0      424973       0.0                424973
# Setúbal               889240.0      874806       0.0                874806
# Viana do Castelo     3362944.0      231266       0.0                231266
# Vila Real            3185096.0      185695       0.0                185695
# Viseu                4478536.0      351292       0.0                351292
# Évora                1115592.0      152444       0.0                152444

# %% [markdown]
#   **Step 2.2.2** Use `groupby()` to obtain a pandas series with the `sum` of column `Population`per `District`

# %%
population.groupby('District')[['Population']].sum() # double square brackets for DF
# Out:
#                      Population
# District
# Aveiro                   692925
# Beja                     144401
# Braga                    846293
# Bragança                 122804
# Castelo Branco           177962
# Coimbra                  408551
# Faro                     467343
# Guarda                   142974
# Ilha Terceira             53234
# Ilha da Graciosa           4090
# Ilha da Madeira          245595
# Ilha das Flores            3428
# Ilha de Porto Santo        5149
# Ilha de Santa Maria        5406
# Ilha de São Jorge          8373
# Ilha de São Miguel       133288
# Ilha do Corvo               384
# Ilha do Faial             14331
# Ilha do Pico              13879
# Leiria                   458605
# Lisboa                  2275385
# Portalegre               104923
# Porto                   1785405
# Santarém                 424973
# Setúbal                  874806
# Viana do Castelo         231266
# Vila Real                185695
# Viseu                    351292
# Évora                    152444

# %% [markdown]
#   **Step 2.2.3** Use `groupby()` to obtain a pandas dataframe with the `sum` of column `Population` per `District`. Sort it in descending order

# %%
population.groupby('District')[['Population']].sum(numeric_only = True).sort(ascending=False) #CODE HERE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7152\3981726542.py in ?()
# ----> 1 population.groupby('District')[['Population']].sum(numeric_only = True).sort(ascending=False) #CODE HERE
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
# **Step 2.2.4** Use `groupby()` to obtain a pandas dataframe with the `sum` of column `Population` per `District` and `Age_bracket`. Store it in variable `population_per_district_age`.

# %%
#storing it in a variable allows you to use it later as any other pandas dataframe as it has too many rows to see in one go
population_per_district_age =  population.groupby(['District', 'Age_bracket'])[['Population']].sum()

#checking the result
population_per_district_age
# Out:
#                            Population
# District Age_bracket
# Aveiro   0 - 14 year old        85047
#          15 - 24 year old       72264
#          25 - 64 year old      374324
#          65 and older          161290
# Beja     0 - 14 year old        17498
# ...                               ...
# Viseu    65 and older           98871
# Évora    0 - 14 year old        18482
#          15 - 24 year old       14812
#          25 - 64 year old       77747
#          65 and older           41403
#
# [116 rows x 1 columns]

# %% [markdown]
# Grouping on multiple columns generates a MultiIndex by default. While MultiIndexes have been covered before, we haven't learned how to deal with them. In this notebook, we will cover the most basic way of removing a multi-index, which is resetting it using `reset_index()`. More info [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html)
#
# **Step 2.2.5** Identify and deal with the MultiIndex in the dataframe `population_per_district_age`<br>
# **Step 2.2.5.1** Check the shape and columns of the dataframe `population_per_district_age` (you should expect it to have single column)

# %%
print(f'Shape of the dataframe: {population_per_district_age.shape}\n' +
      f'Columns in the dataframe: {population_per_district_age.columns.unique()}')
# Out:
# Shape of the dataframe: (116, 1)
# Columns in the dataframe: Index(['Population'], dtype='object')

# %% [markdown]
# **Step 2.2.5.2** Use the method `reset_index()` to remove the MultiIndex and set its components to regular columns of a *pandas* dataframe. Check whether your changes had an effect.

# %%
#resetting index
population_per_district_age.reset_index(inplace=True, drop = False) #the current default is drop = False

#check
print(f'Shape of the dataframe: {population_per_district_age.shape}\n' +
      f'Columns in the dataframe: {population_per_district_age.columns.unique()}')

population_per_district_age
# Out:
# Shape of the dataframe: (116, 3)
# Columns in the dataframe: Index(['District', 'Age_bracket', 'Population'], dtype='object')
#     District       Age_bracket  Population
# 0     Aveiro   0 - 14 year old       85047
# 1     Aveiro  15 - 24 year old       72264
# 2     Aveiro  25 - 64 year old      374324
# 3     Aveiro      65 and older      161290
# 4       Beja   0 - 14 year old       17498
# ..       ...               ...         ...
# 111    Viseu      65 and older       98871
# 112    Évora   0 - 14 year old       18482
# 113    Évora  15 - 24 year old       14812
# 114    Évora  25 - 64 year old       77747
# 115    Évora      65 and older       41403
#
# [116 rows x 3 columns]

# %% [markdown]
# The `groupby` method allows for the grouping to be performed not only over multiple variables, but it allows you to set multiple functions as well using the `agg` parameter. While very useful in order to obtain a more granular insight, it has the **drawback** of possibly generation a column **MultiIndex**, which is much more challenging to handle than the ones covered thus far.
#
# **Step 2.3.1** Use `groupby()` to obtain a pandas dataframe with the `sum`, `mean` and `median` of column `Population` per `District` and `Age_bracket`.

# %%
population.groupby(['District', 'Age_bracket']).agg({
                                                     'Population' : ['sum', 'mean', 'median'],
                                                    })
# Out:
#                           Population
#                                  sum         mean median
# District Age_bracket
# Aveiro   0 - 14 year old       85047   291.256849  197.5
#          15 - 24 year old      72264   247.479452  168.5
#          25 - 64 year old     374324  1281.931507  861.5
#          65 and older         161290   552.363014  392.0
# Beja     0 - 14 year old       17498   116.653333   50.5
# ...                              ...          ...    ...
# Viseu    65 and older          98871   178.467509  120.0
# Évora    0 - 14 year old       18482   133.927536   47.5
#          15 - 24 year old      14812   107.333333   39.0
#          25 - 64 year old      77747   563.384058  234.5
#          65 and older          41403   300.021739  143.0
#
# [116 rows x 3 columns]

# %% [markdown]
# **Step 2.3.2** Use `groupby()` to obtain a pandas dataframe with the `sum`, `mean` and `median` of column `Population` and the number of `Location_Code` and `Parish` per `District`.

# %%
population.groupby(['District']).agg({
                                                     'Population' : ['sum', 'mean', 'median'],
                                                     'Location_Code' : 'nunique', #nunique gives the number of unique values
                                                     'Parish' : 'nunique', #nunique gives the number of unique values
                                                    })
# Out:
#                     Population                      Location_Code  Parish
#                            sum         mean  median       nunique nunique
# District
# Aveiro                  692925   593.257705   323.0           146     145
# Beja                    144401   240.668333   122.5            75      75
# Braga                   846293   304.860591   142.0           347     342
# Bragança                122804    67.922566    30.0           226     225
# Castelo Branco          177962   185.377083    61.5           120     120
# Coimbra                 408551   329.476613   139.0           155     155
# Faro                    467343   871.908582   384.5            67      67
# Guarda                  142974    73.850207    33.0           242     237
# Ilha Terceira            53234   221.808333   127.5            30      30
# Ilha da Graciosa          4090   127.812500   100.0             4       4
# Ilha da Madeira         245595   579.233491   242.5            53      52
# Ilha das Flores           3428    38.954545    16.0            11      11
# Ilha de Porto Santo       5149   643.625000   361.5             1       1
# Ilha de Santa Maria       5406   135.150000    61.0             5       5
# Ilha de São Jorge         8373    95.147727    57.5            11      11
# Ilha de São Miguel      133288   260.328125   132.5            64      62
# Ilha do Corvo              384    48.000000    28.5             1       1
# Ilha do Faial            14331   137.798077    91.0            13      13
# Ilha do Pico             13879   102.051471    56.5            17      17
# Leiria                  458605   521.142045   254.0           110     110
# Lisboa                 2275385  2122.560634  1007.0           134     133
# Portalegre              104923   190.077899    84.5            69      68
# Porto                  1785405   918.418210   273.0           243     238
# Santarém                424973   376.749113   164.0           141     140
# Setúbal                 874806  1988.195455   945.5            55      55
# Viana do Castelo        231266   138.981971    67.0           208     208
# Vila Real               185695   117.826777    55.0           197     196
# Viseu                   351292   158.525271    69.0           277     274
# Évora                   152444   276.166667   109.0            69      69

# %% [markdown]
# ### <font color='#BFD72F'>3. CrossTab and Pivot Tables</font> <a class="anchor" id="P3"></a>
#   [Back to TOC](#toc)
#
# #### CrossTab<a class="anchor" id="P3.1"></a>
#
# By default, cross tabulation creates a frequency table that shows the distribution of data across different categories of those variables.
# Consider the example given in the theoretical class, where you had multiple students and their respective classes.
#
# **Step 3.1.1** Run the cell below to create the dataframe used in the theoretical class.

# %%
#create sample dataframe
crosstab_example = pd.DataFrame(data = {
                                            'Name' : ['John', 'Mary', 'Hanna', 'James', 'Louise', 'Robert', 'Ben', 'Hanna', 'Richard', 'Emily'],
                                            'Class' : ['LGI', 'LGI', 'LSTI', 'LCD', 'LSTI', 'LGI', 'LCD', 'LGI', 'LCD', 'LSTI'],
                                            'P' : ['P1', 'P2', 'P1', 'P1', 'P1', 'P1', 'P2', 'P2', 'P1', 'P2'],
                                             })
#display dataframe
crosstab_example
# Out:
#       Name Class   P
# 0     John   LGI  P1
# 1     Mary   LGI  P2
# 2    Hanna  LSTI  P1
# 3    James   LCD  P1
# 4   Louise  LSTI  P1
# 5   Robert   LGI  P1
# 6      Ben   LCD  P2
# 7    Hanna   LGI  P2
# 8  Richard   LCD  P1
# 9    Emily  LSTI  P2

# %% [markdown]
# **Step 3.1.2** Use `crosstab()` on `crosstab_example` to have the columns be the different `P` each row be `Class`

# %%
pd.crosstab(index = crosstab_example['Class'],
            columns = crosstab_example['P'])
# Out:
# P      P1  P2
# Class
# LCD     2   1
# LGI     2   2
# LSTI    2   1

# %% [markdown]
# A key difference between `crosstab()` and `pivot_table()` is that `crosstab` does not expect dataframes as input. Instead, it expects arrays, series, or lists. This means that you can use `crosstab` to create a table from data that is not already in a dataframe. Check the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html)
#
# **Step 3.2.1** Create two separate lists: the first using data from of `Class` and the second with the data in column `P`

# %%
#list for Class
class_list = crosstab_example['Class'].to_list()

#do the same for p
p_list = crosstab_example['P'].to_list()

# %% [markdown]
# **Step 3.2.2** Use `crosstab()` on lists `class_list` and `p_list` to create replicate the previous crosstab

# %%
pd.crosstab(index = class_list,
            columns = p_list)
# Out:
# col_0  P1  P2
# row_0
# LCD     2   1
# LGI     2   2
# LSTI    2   1

# %% [markdown]
# However, `crosstab()` also allows you to make computations and be used to create pivot tables thanks to the `value` and `aggfunc` parameter.
#
# **Step 3.2** Use `crosstab()` on `population` to create a pivot table where the rows are `District`, the columns are the `Sex` and the values are the *sum* of `Population`

# %%
pd.crosstab(index = population['District'],
            columns = population['Sex'],
            values = population.Population,
            aggfunc = 'sum'
             )
# Out:
# Sex                   Female     Male
# District
# Aveiro                360863   332062
# Beja                   71690    72711
# Braga                 439664   406629
# Bragança               64039    58765
# Castelo Branco         93109    84853
# Coimbra               216077   192474
# Faro                  240568   226775
# Guarda                 75308    67666
# Ilha Terceira          27371    25863
# Ilha da Graciosa        2070     2020
# Ilha da Madeira       130446   115149
# Ilha das Flores         1688     1740
# Ilha de Porto Santo     2613     2536
# Ilha de Santa Maria     2816     2590
# Ilha de São Jorge       4223     4150
# Ilha de São Miguel     68141    65147
# Ilha do Corvo            179      205
# Ilha do Faial           7342     6989
# Ilha do Pico            7103     6776
# Leiria                238731   219874
# Lisboa               1204781  1070604
# Portalegre             55096    49827
# Porto                 938758   846647
# Santarém              222956   202017
# Setúbal               458851   415955
# Viana do Castelo      122911   108355
# Vila Real              97424    88271
# Viseu                 184650   166642
# Évora                  79242    73202

# %% [markdown]
# #### Pivot Tables<a class="anchor" id="P3.2"></a>
#
# `pivot_table()` is a *pandas* function that is designed to create pivot tables from a *DataFrame* (key difference between this method and `crosstab()`). It shares a lot of the syntax used in `crosstab()`, although it is a bit more flexible. To check the documentation, click [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html).
#
# **Step 3.3** Use `pivot_table()` on `population` to create a pivot table where the rows are `District`, the columns are the `Sex` and the values are the *sum* of `Population`

# %%
pd.pivot_table(data = population, 
           index = 'District',
            columns = 'Sex',
            values = 'Population',
            aggfunc = 'sum' 
            )

# Not necessary to break down tables...
# Out:
# Sex                   Female     Male
# District
# Aveiro                360863   332062
# Beja                   71690    72711
# Braga                 439664   406629
# Bragança               64039    58765
# Castelo Branco         93109    84853
# Coimbra               216077   192474
# Faro                  240568   226775
# Guarda                 75308    67666
# Ilha Terceira          27371    25863
# Ilha da Graciosa        2070     2020
# Ilha da Madeira       130446   115149
# Ilha das Flores         1688     1740
# Ilha de Porto Santo     2613     2536
# Ilha de Santa Maria     2816     2590
# Ilha de São Jorge       4223     4150
# Ilha de São Miguel     68141    65147
# Ilha do Corvo            179      205
# Ilha do Faial           7342     6989
# Ilha do Pico            7103     6776
# Leiria                238731   219874
# Lisboa               1204781  1070604
# Portalegre             55096    49827
# Porto                 938758   846647
# Santarém              222956   202017
# Setúbal               458851   415955
# Viana do Castelo      122911   108355
# Vila Real              97424    88271
# Viseu                 184650   166642
# Évora                  79242    73202

# %% [markdown]
# Both `crosstab()` and `pivot_table()` allow the creation of multi-indexed tables. The `crosstab()` function is a special case of the `pivot_table()` function. However, `pivot_table()` has a more forgiving syntax since you can call the column names directly.
#
# **Step 3.4** Use `pivot_table()` on `population` to create a pivot table where the rows are `District`, the columns are `Sex` and `Age_bracket` and the values are the *sum* of `Population`

# %%
pd.pivot_table(
    data=population,
    index='District',
    columns=['Sex', 'Age_bracket'],
    values='Population',
    aggfunc='sum'
)
# Out:
# Sex                          Female                                    \
# Age_bracket         0 - 14 year old 15 - 24 year old 25 - 64 year old
# District
# Aveiro                        41362            35586           193018
# Beja                           8467             6431            35074
# Braga                         52614            46868           243870
# Bragança                       5628             5278            29704
# Castelo Branco                 8881             7536            44023
# Coimbra                       22619            19150           109342
# Faro                          30603            22126           127813
# Guarda                         6637             5961            34652
# Ilha Terceira                  3521             2887            15182
# Ilha da Graciosa                274              205             1091
# Ilha da Madeira               15312            13536            71493
# Ilha das Flores                 203              176              930
# Ilha de Porto Santo             292              254             1528
# Ilha de Santa Maria             387              310             1540
# Ilha de São Jorge               470              403             2321
# Ilha de São Miguel            10121             8407            38797
# Ilha do Corvo                    23               16              109
# Ilha do Faial                   916              719             4078
# Ilha do Pico                    895              665             3808
# Leiria                        27704            22859           122494
# Lisboa                       157971           121186           638533
# Portalegre                     6120             4881            26108
# Porto                        111109            96126           516990
# Santarém                      25440            20605           109808
# Setúbal                       60814            45501           239745
# Viana do Castelo              12671            10952            61475
# Vila Real                      9069             8407            47999
# Viseu                         19353            17350            91878
# Évora                          8904             7107            39537
#
# Sex                                         Male                   \
# Age_bracket         65 and older 0 - 14 year old 15 - 24 year old
# District
# Aveiro                     90897           43685            36678
# Beja                       21718            9031             7436
# Braga                      96312           56082            49273
# Bragança                   23429            5825             5403
# Castelo Branco             32669            9334             8164
# Coimbra                    64966           23958            19730
# Faro                       60026           32178            23703
# Guarda                     28058            6714             6308
# Ilha Terceira               5781            3605             3008
# Ilha da Graciosa             500             317              219
# Ilha da Madeira            30105           16044            14106
# Ilha das Flores              379             232              164
# Ilha de Porto Santo          539             290              293
# Ilha de Santa Maria          579             385              309
# Ilha de São Jorge           1029             575              423
# Ilha de São Miguel         10816           10643             8824
# Ilha do Corvo                 31              26               29
# Ilha do Faial               1629            1013              799
# Ilha do Pico                1735             947              676
# Leiria                     65674           29058            24374
# Lisboa                    287091          166310           124879
# Portalegre                 17987            6256             4970
# Porto                     214533          116125            99855
# Santarém                   67103           26498            22259
# Setúbal                   112791           63853            47815
# Viana do Castelo           37813           13160            11386
# Vila Real                  31949            9606             8745
# Viseu                      56069           20325            18174
# Évora                      23694            9578             7705
#
# Sex
# Age_bracket         25 - 64 year old 65 and older
# District
# Aveiro                        181306        70393
# Beja                           39579        16665
# Braga                         227244        74030
# Bragança                       28683        18854
# Castelo Branco                 42585        24770
# Coimbra                       100813        47973
# Faro                          119971        50923
# Guarda                         33555        21089
# Ilha Terceira                  14948         4302
# Ilha da Graciosa                1094          390
# Ilha da Madeira                66013        18986
# Ilha das Flores                 1044          300
# Ilha de Porto Santo             1523          430
# Ilha de Santa Maria             1530          366
# Ilha de São Jorge               2337          815
# Ilha de São Miguel             37769         7911
# Ilha do Corvo                    122           28
# Ilha do Faial                   3949         1228
# Ilha do Pico                    3863         1290
# Leiria                        115189        51253
# Lisboa                        577504       201911
# Portalegre                     25210        13391
# Porto                         469650       161017
# Santarém                      104160        49100
# Setúbal                       218378        85909
# Viana do Castelo               56543        27266
# Vila Real                      44959        24961
# Viseu                          85341        42802
# Évora                          38210        17709

# %% [markdown]
# **Note** Order when creating these MultiIndexes matters. The first index is the outermost, the last index is the innermost.
# **Step 3.5** Use `pivot_table()` to create the same pivot table you had just created. However, this time, make the columns be `Age_bracket` first and `Sex` second

# %%
pd.pivot_table(
    data = population,
    columns = ['Age_bracket', 'Sex'],
    index = 'District',
    values = 'Population',
    aggfunc = 'sum'
)
# Out:
# Age_bracket         0 - 14 year old         15 - 24 year old          \
# Sex                          Female    Male           Female    Male
# District
# Aveiro                        41362   43685            35586   36678
# Beja                           8467    9031             6431    7436
# Braga                         52614   56082            46868   49273
# Bragança                       5628    5825             5278    5403
# Castelo Branco                 8881    9334             7536    8164
# Coimbra                       22619   23958            19150   19730
# Faro                          30603   32178            22126   23703
# Guarda                         6637    6714             5961    6308
# Ilha Terceira                  3521    3605             2887    3008
# Ilha da Graciosa                274     317              205     219
# Ilha da Madeira               15312   16044            13536   14106
# Ilha das Flores                 203     232              176     164
# Ilha de Porto Santo             292     290              254     293
# Ilha de Santa Maria             387     385              310     309
# Ilha de São Jorge               470     575              403     423
# Ilha de São Miguel            10121   10643             8407    8824
# Ilha do Corvo                    23      26               16      29
# Ilha do Faial                   916    1013              719     799
# Ilha do Pico                    895     947              665     676
# Leiria                        27704   29058            22859   24374
# Lisboa                       157971  166310           121186  124879
# Portalegre                     6120    6256             4881    4970
# Porto                        111109  116125            96126   99855
# Santarém                      25440   26498            20605   22259
# Setúbal                       60814   63853            45501   47815
# Viana do Castelo              12671   13160            10952   11386
# Vila Real                      9069    9606             8407    8745
# Viseu                         19353   20325            17350   18174
# Évora                          8904    9578             7107    7705
#
# Age_bracket         25 - 64 year old         65 and older
# Sex                           Female    Male       Female    Male
# District
# Aveiro                        193018  181306        90897   70393
# Beja                           35074   39579        21718   16665
# Braga                         243870  227244        96312   74030
# Bragança                       29704   28683        23429   18854
# Castelo Branco                 44023   42585        32669   24770
# Coimbra                       109342  100813        64966   47973
# Faro                          127813  119971        60026   50923
# Guarda                         34652   33555        28058   21089
# Ilha Terceira                  15182   14948         5781    4302
# Ilha da Graciosa                1091    1094          500     390
# Ilha da Madeira                71493   66013        30105   18986
# Ilha das Flores                  930    1044          379     300
# Ilha de Porto Santo             1528    1523          539     430
# Ilha de Santa Maria             1540    1530          579     366
# Ilha de São Jorge               2321    2337         1029     815
# Ilha de São Miguel             38797   37769        10816    7911
# Ilha do Corvo                    109     122           31      28
# Ilha do Faial                   4078    3949         1629    1228
# Ilha do Pico                    3808    3863         1735    1290
# Leiria                        122494  115189        65674   51253
# Lisboa                        638533  577504       287091  201911
# Portalegre                     26108   25210        17987   13391
# Porto                         516990  469650       214533  161017
# Santarém                      109808  104160        67103   49100
# Setúbal                       239745  218378       112791   85909
# Viana do Castelo               61475   56543        37813   27266
# Vila Real                      47999   44959        31949   24961
# Viseu                          91878   85341        56069   42802
# Évora                          39537   38210        23694   17709

# %% [markdown]
# ### <font color='#BFD72F'>4.Grabbing subsets - Advanced options</font> <a class="anchor" id="P4"></a>
#   [Back to TOC](#toc)
#
#   In this section, we will explore a few more advanced options to grab subsets of data. In particular, we will use the following methods:
#   1. `query` to grab subsets of data based on a condition or set of conditions
#   2. `isin` to make explicit lists of values to grab
#   3. `between` to grab subsets of data based on a range of values
#
#   **Step 4.1** Use query to obtain subsets of data based on a condition or set of conditions.<br>
#   **Step 4.1.1** Select all rows where the `District` is `Lisboa`

# %%
population.query(expr='District=="Lisboa"')

# equivalent notation
population[population['District']=='Lisboa']

# use loc if i want to do further selections
# Out:
#          Year Location_Code District         Municipality  \
# 6518   2021.0        111409   Lisboa  Vila Franca de Xira
# 7094   2021.0        111409   Lisboa  Vila Franca de Xira
# 10408  2021.0        111409   Lisboa  Vila Franca de Xira
# 14336  2021.0        111409   Lisboa  Vila Franca de Xira
# 15841  2021.0        111409   Lisboa  Vila Franca de Xira
# ...       ...           ...      ...                  ...
# 8631   2021.0        110106   Lisboa             Alenquer
# 10248  2021.0        110106   Lisboa             Alenquer
# 19353  2021.0        110106   Lisboa             Alenquer
# 21332  2021.0        110106   Lisboa             Alenquer
# 24134  2021.0        110106   Lisboa             Alenquer
#
#                     Parish     Sex       Age_bracket  Population  Comments  \
# 6518   Vila Franca de Xira  Female  25 - 64 year old        5063       NaN
# 7094   Vila Franca de Xira    Male   0 - 14 year old        1323       NaN
# 10408  Vila Franca de Xira  Female  15 - 24 year old         974       NaN
# 14336  Vila Franca de Xira    Male  15 - 24 year old         988       NaN
# 15841  Vila Franca de Xira    Male  25 - 64 year old        4495       NaN
# ...                    ...     ...               ...         ...       ...
# 8631               Carnota  Female   0 - 14 year old          72       NaN
# 10248              Carnota  Female  25 - 64 year old         397       NaN
# 19353              Carnota    Male      65 and older         209       NaN
# 21332              Carnota  Female      65 and older         255       NaN
# 24134              Carnota  Female  15 - 24 year old          63       NaN
#
#        Population_corrected
# 6518                   5063
# 7094                   1323
# 10408                   974
# 14336                   988
# 15841                  4495
# ...                     ...
# 8631                     72
# 10248                   397
# 19353                   209
# 21332                   255
# 24134                    63
#
# [1072 rows x 10 columns]

# %% [markdown]
#   **Step 4.1.2** Select all rows where the `District` is `Lisboa` and the `Population` is greater or equal than 2000 people.

# %%
population.query('District == "Lisboa" and Population >= 2000') #CODE HERE
# Out:
#          Year Location_Code District         Municipality  \
# 6518   2021.0        111409   Lisboa  Vila Franca de Xira
# 15841  2021.0        111409   Lisboa  Vila Franca de Xira
# 17798  2021.0        111409   Lisboa  Vila Franca de Xira
# 4467   2021.0        111408   Lisboa  Vila Franca de Xira
# 12404  2021.0        111408   Lisboa  Vila Franca de Xira
# ...       ...           ...      ...                  ...
# 21972  2021.0        111512   Lisboa              Amadora
# 14007  2021.0        110120   Lisboa             Alenquer
# 17708  2021.0        110120   Lisboa             Alenquer
# 1591   2021.0        110119   Lisboa             Alenquer
# 21863  2021.0        110119   Lisboa             Alenquer
#
#                                                   Parish     Sex  \
# 6518                                 Vila Franca de Xira  Female
# 15841                                Vila Franca de Xira    Male
# 17798                                Vila Franca de Xira  Female
# 4467                                            Vialonga    Male
# 12404                                           Vialonga    Male
# ...                                                  ...     ...
# 21972                                          Alfragide    Male
# 14007       União das freguesias de Carregado e Cadafais    Male
# 17708       União das freguesias de Carregado e Cadafais  Female
# 1591   União das freguesias de Alenquer (Santo Estêvã...  Female
# 21863  União das freguesias de Alenquer (Santo Estêvã...    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 6518   25 - 64 year old        5063       NaN                  5063
# 15841  25 - 64 year old        4495       NaN                  4495
# 17798      65 and older        2480       NaN                  2480
# 4467    0 - 14 year old        2052       NaN                  2052
# 12404  25 - 64 year old        5533       NaN                  5533
# ...                 ...         ...       ...                   ...
# 21972  25 - 64 year old        4272       NaN                  4272
# 14007  25 - 64 year old        4000       NaN                  4000
# 17708  25 - 64 year old        4318       NaN                  4318
# 1591   25 - 64 year old        3406       NaN                  3406
# 21863  25 - 64 year old        3164       NaN                  3164
#
# [349 rows x 10 columns]

# %% [markdown]
#   **Step 4.1.3** Select all rows where the `Population` is greater or equal than 2000 people and the `District` is `Lisboa` or `Porto`.

# %%
population.query('Population >= 2000 and (District == "Lisboa" or District == "Porto")')
# Out:
#          Year Location_Code District   Municipality  \
# 1669   2021.0        131628    Porto  Vila do Conde
# 6806   2021.0        131628    Porto  Vila do Conde
# 7657   2021.0        131628    Porto  Vila do Conde
# 11004  2021.0        131628    Porto  Vila do Conde
# 11495  2021.0        131628    Porto  Vila do Conde
# ...       ...           ...      ...            ...
# 21972  2021.0        111512   Lisboa        Amadora
# 14007  2021.0        110120   Lisboa       Alenquer
# 17708  2021.0        110120   Lisboa       Alenquer
# 1591   2021.0        110119   Lisboa       Alenquer
# 21863  2021.0        110119   Lisboa       Alenquer
#
#                                                   Parish     Sex  \
# 1669                                       Vila do Conde  Female
# 6806                                       Vila do Conde  Female
# 7657                                       Vila do Conde    Male
# 11004                                      Vila do Conde    Male
# 11495                                      Vila do Conde  Female
# ...                                                  ...     ...
# 21972                                          Alfragide    Male
# 14007       União das freguesias de Carregado e Cadafais    Male
# 17708       União das freguesias de Carregado e Cadafais  Female
# 1591   União das freguesias de Alenquer (Santo Estêvã...  Female
# 21863  União das freguesias de Alenquer (Santo Estêvã...    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 1669   25 - 64 year old        8423       NaN                  8423
# 6806       65 and older        3417       NaN                  3417
# 7657   25 - 64 year old        7649       NaN                  7649
# 11004      65 and older        2422       NaN                  2422
# 11495   0 - 14 year old        2058       NaN                  2058
# ...                 ...         ...       ...                   ...
# 21972  25 - 64 year old        4272       NaN                  4272
# 14007  25 - 64 year old        4000       NaN                  4000
# 17708  25 - 64 year old        4318       NaN                  4318
# 1591   25 - 64 year old        3406       NaN                  3406
# 21863  25 - 64 year old        3164       NaN                  3164
#
# [576 rows x 10 columns]

# %% [markdown]
#   **Step 4.2** Use standard dataframe slicing to obtain subsets of data based on a condition or set of conditions.<br>
#     **Step 4.2.1** Select all rows where the `District` is `Coimbra`

# %%
population.query('District=="Coimbra"')
# Out:
#          Year Location_Code District          Municipality  \
# 1779   2021.0         61704  Coimbra  Vila Nova de Poiares
# 8525   2021.0         61704  Coimbra  Vila Nova de Poiares
# 10475  2021.0         61704  Coimbra  Vila Nova de Poiares
# 10488  2021.0         61704  Coimbra  Vila Nova de Poiares
# 15764  2021.0         61704  Coimbra  Vila Nova de Poiares
# ...       ...           ...      ...                   ...
# 13257  2021.0         60102  Coimbra               Arganil
# 15456  2021.0         60102  Coimbra               Arganil
# 18608  2021.0         60102  Coimbra               Arganil
# 22219  2021.0         60102  Coimbra               Arganil
# 24601  2021.0         60102  Coimbra               Arganil
#
#                       Parish     Sex       Age_bracket  Population  Comments  \
# 1779   São Miguel de Poiares  Female  25 - 64 year old         350       NaN
# 8525   São Miguel de Poiares  Female      65 and older         205       NaN
# 10475  São Miguel de Poiares    Male  25 - 64 year old         314       NaN
# 10488  São Miguel de Poiares  Female   0 - 14 year old          78       NaN
# 15764  São Miguel de Poiares    Male   0 - 14 year old          77       NaN
# ...                      ...     ...               ...         ...       ...
# 13257                Arganil  Female  15 - 24 year old         180       NaN
# 15456                Arganil    Male      65 and older         429       NaN
# 18608                Arganil  Female      65 and older         570       NaN
# 22219                Arganil    Male  25 - 64 year old         968       NaN
# 24601                Arganil    Male  15 - 24 year old         197       NaN
#
#        Population_corrected
# 1779                    350
# 8525                    205
# 10475                   314
# 10488                    78
# 15764                    77
# ...                     ...
# 13257                   180
# 15456                   429
# 18608                   570
# 22219                   968
# 24601                   197
#
# [1240 rows x 10 columns]

# %% [markdown]
#   **Step 4.2.2** Select all rows where the `District` is `Coimbra` and the `Population` is equal or smaller than 300 people.

# %%
population.query('District=="Coimbra" & (Population<300 or Population==300)')
# Out:
#          Year Location_Code District          Municipality  \
# 8525   2021.0         61704  Coimbra  Vila Nova de Poiares
# 10488  2021.0         61704  Coimbra  Vila Nova de Poiares
# 15764  2021.0         61704  Coimbra  Vila Nova de Poiares
# 19539  2021.0         61704  Coimbra  Vila Nova de Poiares
# 19735  2021.0         61704  Coimbra  Vila Nova de Poiares
# ...       ...           ...      ...                   ...
# 21400  2021.0         60104  Coimbra               Arganil
# 1673   2021.0         60102  Coimbra               Arganil
# 3732   2021.0         60102  Coimbra               Arganil
# 13257  2021.0         60102  Coimbra               Arganil
# 24601  2021.0         60102  Coimbra               Arganil
#
#                       Parish     Sex       Age_bracket  Population  Comments  \
# 8525   São Miguel de Poiares  Female      65 and older         205       NaN
# 10488  São Miguel de Poiares  Female   0 - 14 year old          78       NaN
# 15764  São Miguel de Poiares    Male   0 - 14 year old          77       NaN
# 19539  São Miguel de Poiares  Female  15 - 24 year old          52       NaN
# 19735  São Miguel de Poiares    Male  15 - 24 year old          77       NaN
# ...                      ...     ...               ...         ...       ...
# 21400               Benfeita  Female  15 - 24 year old           1       NaN
# 1673                 Arganil  Female   0 - 14 year old         228       NaN
# 3732                 Arganil    Male   0 - 14 year old         223       NaN
# 13257                Arganil  Female  15 - 24 year old         180       NaN
# 24601                Arganil    Male  15 - 24 year old         197       NaN
#
#        Population_corrected
# 8525                    205
# 10488                    78
# 15764                    77
# 19539                    52
# 19735                    77
# ...                     ...
# 21400                     1
# 1673                    228
# 3732                    223
# 13257                   180
# 24601                   197
#
# [907 rows x 10 columns]

# %% [markdown]
#   **Step 4.2.3** Select all rows where the `Population` is inferior or equal than 300 people and the `District` is `Coimbra` or `Aveiro`.

# %%
population[(population['Population'] <= 300) & ((population['District'] == 'Coimbra') | (population['District'] == 'Aveiro'))]
# Out:
#          Year Location_Code District          Municipality  \
# 8525   2021.0         61704  Coimbra  Vila Nova de Poiares
# 10488  2021.0         61704  Coimbra  Vila Nova de Poiares
# 15764  2021.0         61704  Coimbra  Vila Nova de Poiares
# 19539  2021.0         61704  Coimbra  Vila Nova de Poiares
# 19735  2021.0         61704  Coimbra  Vila Nova de Poiares
# ...       ...           ...      ...                   ...
# 7634   2021.0         10202   Aveiro    Albergaria-a-Velha
# 10768  2021.0         10202   Aveiro    Albergaria-a-Velha
# 15185  2021.0         10202   Aveiro    Albergaria-a-Velha
# 19906  2021.0         10202   Aveiro    Albergaria-a-Velha
# 21580  2021.0         10202   Aveiro    Albergaria-a-Velha
#
#                       Parish     Sex       Age_bracket  Population  Comments  \
# 8525   São Miguel de Poiares  Female      65 and older         205       NaN
# 10488  São Miguel de Poiares  Female   0 - 14 year old          78       NaN
# 15764  São Miguel de Poiares    Male   0 - 14 year old          77       NaN
# 19539  São Miguel de Poiares  Female  15 - 24 year old          52       NaN
# 19735  São Miguel de Poiares    Male  15 - 24 year old          77       NaN
# ...                      ...     ...               ...         ...       ...
# 7634              Alquerubim  Female   0 - 14 year old         118       NaN
# 10768             Alquerubim  Female  15 - 24 year old         116       NaN
# 15185             Alquerubim    Male      65 and older         258       NaN
# 19906             Alquerubim    Male   0 - 14 year old         141       NaN
# 21580             Alquerubim    Male  15 - 24 year old         110       NaN
#
#        Population_corrected
# 8525                    205
# 10488                    78
# 15764                    77
# 19539                    52
# 19735                    77
# ...                     ...
# 7634                    118
# 10768                   116
# 15185                   258
# 19906                   141
# 21580                   110
#
# [1453 rows x 10 columns]

# %% [markdown]
# There is are also functions that allow you to effortlessly create more elaborate conditions. One possibility is using `isin` to give a boolean mask that you can use to filter the dataframe based on a set of values you want to check for. More info on this method can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isin.html).
#
# **Step 4.3.1** Use the `isin` function to create a boolean mask that you can use to filter the dataframe. The mask should be true for all rows where the `District` column is either `Coimbra` or `Leiria`. Use that mask to filter the dataframe `population`.

# %%
population['District'].isin(['Coimbra', 'Leiria']) #CODE HERE

# to use it i put it inside square brackets
# Out:
# 3232     False
# 7672     False
# 13912    False
# 14498    False
# 16065    False
#          ...
# 4904     False
# 14888    False
# 15395    False
# 21325    False
# 22975    False
# Name: District, Length: 24728, dtype: bool

# %% [markdown]
# An alternative, and more elegant way is to create a list with the values you want to check for and use that list as the input to the isin() method. Try it.

# %%
#create list (try and change it to look for different values)
districts_to_check = ['Coimbra', 'Leiria']

#filter
population[population['District'].isin(districts_to_check)]#CODE HERE
# Out:
#          Year Location_Code District Municipality   Parish     Sex  \
# 2629   2021.0        101207   Leiria       Óbidos      Vau  Female
# 3390   2021.0        101207   Leiria       Óbidos      Vau  Female
# 4597   2021.0        101207   Leiria       Óbidos      Vau  Female
# 7362   2021.0        101207   Leiria       Óbidos      Vau  Female
# 14849  2021.0        101207   Leiria       Óbidos      Vau    Male
# ...       ...           ...      ...          ...      ...     ...
# 13257  2021.0         60102  Coimbra      Arganil  Arganil  Female
# 15456  2021.0         60102  Coimbra      Arganil  Arganil    Male
# 18608  2021.0         60102  Coimbra      Arganil  Arganil  Female
# 22219  2021.0         60102  Coimbra      Arganil  Arganil    Male
# 24601  2021.0         60102  Coimbra      Arganil  Arganil    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 2629    0 - 14 year old          44       NaN                    44
# 3390   25 - 64 year old         232       NaN                   232
# 4597       65 and older         142       NaN                   142
# 7362   15 - 24 year old          39       NaN                    39
# 14849   0 - 14 year old          56       NaN                    56
# ...                 ...         ...       ...                   ...
# 13257  15 - 24 year old         180       NaN                   180
# 15456      65 and older         429       NaN                   429
# 18608      65 and older         570       NaN                   570
# 22219  25 - 64 year old         968       NaN                   968
# 24601  15 - 24 year old         197       NaN                   197
#
# [2120 rows x 10 columns]

# %% [markdown]
# Another example, now for numerical values is the method `between()`. More info on this method can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.between.html).
#
# **Step 4.3.1** Use the `between()` function to create a boolean mask that you can use to filter the dataframe. Only the rows where `Population` values are between 100 and 200 should be returned

# %%
population[population['Population'].between(100, 200)]
# Out:
#          Year Location_Code District        Municipality  \
# 21931  2021.0         70523    Évora               Évora
# 23796  2021.0         70523    Évora               Évora
# 4662   2021.0         70527    Évora               Évora
# 15786  2021.0         70527    Évora               Évora
# 1585   2021.0         70526    Évora               Évora
# ...       ...           ...      ...                 ...
# 23238  2021.0         10210   Aveiro  Albergaria-a-Velha
# 7634   2021.0         10202   Aveiro  Albergaria-a-Velha
# 10768  2021.0         10202   Aveiro  Albergaria-a-Velha
# 19906  2021.0         10202   Aveiro  Albergaria-a-Velha
# 21580  2021.0         10202   Aveiro  Albergaria-a-Velha
#
#                                                   Parish     Sex  \
# 21931  União das freguesias de Évora (São Mamede, Sé,...  Female
# 23796  União das freguesias de Évora (São Mamede, Sé,...    Male
# 4662   União das freguesias de São Sebastião da Giest...  Female
# 15786  União das freguesias de São Sebastião da Giest...    Male
# 1585   União das freguesias de São Manços e São Vicen...    Male
# ...                                                  ...     ...
# 23238                        São João de Loure e Frossos  Female
# 7634                                          Alquerubim  Female
# 10768                                         Alquerubim  Female
# 19906                                         Alquerubim    Male
# 21580                                         Alquerubim    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 21931   0 - 14 year old         189       NaN                   189
# 23796  15 - 24 year old         192       NaN                   192
# 4662       65 and older         172       NaN                   172
# 15786      65 and older         125       NaN                   125
# 1585       65 and older         145       NaN                   145
# ...                 ...         ...       ...                   ...
# 23238   0 - 14 year old         171       NaN                   171
# 7634    0 - 14 year old         118       NaN                   118
# 10768  15 - 24 year old         116       NaN                   116
# 19906   0 - 14 year old         141       NaN                   141
# 21580  15 - 24 year old         110       NaN                   110
#
# [4582 rows x 10 columns]

# %% [markdown]
# An alternative, and more elegant way is to assign the values you want to search in variables and then use those variables as the inputs to `between`. Try it.

# %%
#assign values to the variables
max_value = 200
min_value = 100

#search for the values
population.Population.between(min_value,max_value)
# Out:
# 3232     False
# 7672     False
# 13912    False
# 14498    False
# 16065    False
#          ...
# 4904     False
# 14888    False
# 15395    False
# 21325    False
# 22975    False
# Name: Population, Length: 24728, dtype: bool

# %% [markdown]
# You can also combine these two methods for more powerful queries to your data.
#
# **Step 4.3** Return the rows in the dataset that are in districts `Évora`, `Beja` and `Faro` whose `Population` is between 50 and 150 inhabitants.

# %%
#set search space
districts_to_check = ['Évora', 'Beja', 'Faro']
min_value = 50
max_value = 150

#search for the values
mask1 = population.District.isin(['Évora', 'Beja', 'Faro'])
mask2 = population.Population.between(min_value, max_value)

population[mask1 & mask2]
# Out:
#          Year Location_Code District Municipality  \
# 15786  2021.0         70527    Évora        Évora
# 1585   2021.0         70526    Évora        Évora
# 5823   2021.0         70526    Évora        Évora
# 6732   2021.0         70526    Évora        Évora
# 7830   2021.0         70526    Évora        Évora
# ...       ...           ...      ...          ...
# 17484  2021.0         20104     Beja    Aljustrel
# 22913  2021.0         20104     Beja    Aljustrel
# 2865   2021.0         20103     Beja    Aljustrel
# 4738   2021.0         20103     Beja    Aljustrel
# 1655   2021.0         20102     Beja    Aljustrel
#
#                                                   Parish     Sex  \
# 15786  União das freguesias de São Sebastião da Giest...    Male
# 1585   União das freguesias de São Manços e São Vicen...    Male
# 5823   União das freguesias de São Manços e São Vicen...    Male
# 6732   União das freguesias de São Manços e São Vicen...  Female
# 7830   União das freguesias de São Manços e São Vicen...    Male
# ...                                                  ...     ...
# 17484                              São João de Negrilhos    Male
# 22913                              São João de Negrilhos  Female
# 2865                                           Messejana  Female
# 4738                                           Messejana    Male
# 1655                                             Ervidel    Male
#
#             Age_bracket  Population  Comments  Population_corrected
# 15786      65 and older         125       NaN                   125
# 1585       65 and older         145       NaN                   145
# 5823   15 - 24 year old          57       NaN                    57
# 6732    0 - 14 year old          59       NaN                    59
# 7830    0 - 14 year old          54       NaN                    54
# ...                 ...         ...       ...                   ...
# 17484   0 - 14 year old          71       NaN                    71
# 22913   0 - 14 year old          75       NaN                    75
# 2865    0 - 14 year old          50       NaN                    50
# 4738       65 and older         123       NaN                   123
# 1655       65 and older         133       NaN                   133
#
# [468 rows x 10 columns]

# %% [markdown]
# ### <font color='#BFD72F'>5.Try it out</font> <a class="anchor" id="P5"></a>
#   [Back to TOC](#toc)
#
# 1. Create a pivot_table whose values are the `sum` of the population separated by **males** and **females** for each `District`, `Municipality`, `Parish`. Store it in variable `exercise_pivot`

# %%
population = pd.read_csv(r"./data/pop_censuspt_2021.csv", sep=";")
population.head(1)
# Out:
#    Year Location_Code   District Municipality Parish Sex           Age  \
# 0  2021        170320  Vila Real       Chaves   Oura   F  65 and older
#
#    Population  Notes  Population_corrected
# 0         100    NaN                   100

# %%
exercise_pivot = population.pivot_table(
    index = ["District", "Municipality", "Parish"],
    columns= "Sex",
    values = "Population",
    aggfunc = "sum",
)

exercise_pivot
# Out:
# Sex                                                                                 F  \
# District Municipality       Parish
# Aveiro   Albergaria-a-Velha Albergaria-a-Velha e Valmaior                        5720
#                             Alquerubim                                           1137
#                             Angeja                                                984
#                             Branca                                               2770
#                             Ribeira de Fráguas                                    749
# ...                                                                               ...
# Évora    Évora              União das freguesias de Malagueira e Horta das ...  11352
#                             União das freguesias de Nossa Senhora da Toureg...    513
#                             União das freguesias de São Manços e São Vicent...    547
#                             União das freguesias de São Sebastião da Gieste...    472
#                             União das freguesias de Évora (São Mamede, Sé, ...   2376
#
# Sex                                                                                 M
# District Municipality       Parish
# Aveiro   Albergaria-a-Velha Albergaria-a-Velha e Valmaior                        5338
#                             Alquerubim                                           1096
#                             Angeja                                                891
#                             Branca                                               2657
#                             Ribeira de Fráguas                                    745
# ...                                                                               ...
# Évora    Évora              União das freguesias de Malagueira e Horta das ...  10195
#                             União das freguesias de Nossa Senhora da Toureg...    482
#                             União das freguesias de São Manços e São Vicent...    533
#                             União das freguesias de São Sebastião da Gieste...    455
#                             União das freguesias de Évora (São Mamede, Sé, ...   1939
#
# [3091 rows x 2 columns]

# %% [markdown]
# 2. Create a new column in `exercise_pivot` with the total population of each parish. What are the 10 most populated parishes and to what municipality and district do they belong to? <br>
# **Hint**: You may need to revise your answer to question 1 to get the correct answer to this question.

# %%
#computing new column
exercise_pivot["Parish_Population"] = exercise_pivot.F + exercise_pivot.M
exercise_pivot.sort_values(by="Parish_Population", ascending = False).head(10) # Answer
# Out:
# Sex                                                                                F  \
# District Municipality      Parish
# Lisboa   Sintra            Algueirão-Mem Martins                               36259
#          Cascais           União das freguesias de Cascais e Estoril           34576
#          Odivelas          Odivelas                                            31710
#          Cascais           São Domingos de Rana                                31328
#          Oeiras            União das freguesias de Oeiras e São Julião da ...  31488
# Porto    Vila Nova de Gaia União das freguesias de Mafamude e Vilar do Par...  28401
# Setúbal  Setúbal           Setúbal (São Sebastião)                             27586
# Lisboa   Sintra            União das freguesias de Queluz e Belas              27694
# Porto    Gondomar          Rio Tinto                                           27250
# Setúbal  Seixal            Corroios                                            26829
#
# Sex                                                                                M  \
# District Municipality      Parish
# Lisboa   Sintra            Algueirão-Mem Martins                               32390
#          Cascais           União das freguesias de Cascais e Estoril           29616
#          Odivelas          Odivelas                                            27876
#          Cascais           São Domingos de Rana                                27910
#          Oeiras            União das freguesias de Oeiras e São Julião da ...  26606
# Porto    Vila Nova de Gaia União das freguesias de Mafamude e Vilar do Par...  24443
# Setúbal  Setúbal           Setúbal (São Sebastião)                             25041
# Lisboa   Sintra            União das freguesias de Queluz e Belas              24720
# Porto    Gondomar          Rio Tinto                                           23833
# Setúbal  Seixal            Corroios                                            23977
#
# Sex                                                                            Parish_Population
# District Municipality      Parish
# Lisboa   Sintra            Algueirão-Mem Martins                                           68649
#          Cascais           União das freguesias de Cascais e Estoril                       64192
#          Odivelas          Odivelas                                                        59586
#          Cascais           São Domingos de Rana                                            59238
#          Oeiras            União das freguesias de Oeiras e São Julião da ...              58094
# Porto    Vila Nova de Gaia União das freguesias de Mafamude e Vilar do Par...              52844
# Setúbal  Setúbal           Setúbal (São Sebastião)                                         52627
# Lisboa   Sintra            União das freguesias de Queluz e Belas                          52414
# Porto    Gondomar          Rio Tinto                                                       51083
# Setúbal  Seixal            Corroios                                                        50806

# %% [markdown]
# 3. Filter the dataframe `exercise_pivot` in a way that only the parishes with more females than males appear. Sort them in ascending order of total population.

# %%
y = exercise_pivot.query("F>M").sort_values(by="Parish_Population", ascending=True).head(5)
y
# Out:
# Sex                                                                                  F  \
# District        Municipality          Parish
# Ilha das Flores Lajes das Flores      Fajãzinha                                     38
#                 Santa Cruz das Flores Caveira                                       40
# Viseu           Tabuaço               União das freguesias de Paradela e Granjinha  51
# Guarda          Trancoso              Granja                                        58
# Bragança        Vimioso               Vilar Seco                                    60
#
# Sex                                                                                  M  \
# District        Municipality          Parish
# Ilha das Flores Lajes das Flores      Fajãzinha                                     33
#                 Santa Cruz das Flores Caveira                                       36
# Viseu           Tabuaço               União das freguesias de Paradela e Granjinha  48
# Guarda          Trancoso              Granja                                        51
# Bragança        Vimioso               Vilar Seco                                    56
#
# Sex                                                                                 Parish_Population
# District        Municipality          Parish
# Ilha das Flores Lajes das Flores      Fajãzinha                                                    71
#                 Santa Cruz das Flores Caveira                                                      76
# Viseu           Tabuaço               União das freguesias de Paradela e Granjinha                 99
# Guarda          Trancoso              Granja                                                      109
# Bragança        Vimioso               Vilar Seco                                                  116

# %% [markdown]
# 4. Find the 5 most common `Parish` names and the number of times they appear<br>
# **Hint**: You may need to reset the index of the dataframe

# %%
exercise_pivot.reset_index().Parish.value_counts().sort_values(ascending=False)
# Out:
# Parish
# Pinheiro                                                                   6
# Santa Bárbara                                                              5
# Rio de Moinhos                                                             5
# Carvalhal                                                                  5
# Santo António                                                              4
#                                                                           ..
# Vale de Figueira                                                           1
# Valongo dos Azeites                                                        1
# Bordonhos                                                                  1
# Figueiredo de Alva                                                         1
# União das freguesias de Évora (São Mamede, Sé, São Pedro e Santo Antão)    1
# Name: count, Length: 2873, dtype: int64

# %% [markdown]
# ### That's it for this week. Don't forget to practice!
